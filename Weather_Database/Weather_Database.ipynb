# %%
#Import Dependencies
from citipy import citipy
import random
import numpy as np
import timeit
import pandas as pd
import matplotlib.pyplot as plt

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
#for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
   # if (i % 50 == 0 and i >= 50):
       # set_count += 1
       # record_count = 1

    # Create endpoint URL with each city.
   # city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | viransehir
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 1 | saint-joseph
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | garissa
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 1 | necochea
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | ambilobe
# Processing Record 18 of Set 1 | yuanping
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | chuy
# Processing Record 22 of Set 1 | aklavik
# Processing Record 23 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 24 of Set 1 | sanhsia
# City not found. Skipping...
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | chateauroux
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | sao jose da coroa grande
# Processing Record 30 of Set 1 | matamoros
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | murray bridge
# Processing Record 33 of Set 1 | shaoguan
# Processing Record 34 of Set 1 | grand bend
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | vardo
# Processing Record 37 of Set 1 | bengkulu
# Processing Record 38 of Set 1 | victor harbor
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | ust-tsilma
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | tahta
# Processing Record 48 of Set 1 | fort nelson
# Processing Record 49 of Set 1 | taonan
# Processing Record 50 of Set 1 | souillac
# Processing Record 1 of Set 2 | the valley
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | dickinson
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | conakry
# Processing Record 7 of Set 2 | oranjestad
# Processing Record 8 of Set 2 | bandarbeyla
# Processing Record 9 of Set 2 | kutum
# Processing Record 10 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 2 | gaborone
# Processing Record 12 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 2 | livingstone
# Processing Record 14 of Set 2 | caravelas
# Processing Record 15 of Set 2 | salalah
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | yulara
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | moiyabana
# City not found. Skipping...
# Processing Record 20 of Set 2 | muros
# Processing Record 21 of Set 2 | inta
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | houma
# Processing Record 24 of Set 2 | aketi
# Processing Record 25 of Set 2 | esperance
# Processing Record 26 of Set 2 | mindelo
# Processing Record 27 of Set 2 | beringovskiy
# Processing Record 28 of Set 2 | isangel
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | acapulco
# Processing Record 31 of Set 2 | san cristobal
# Processing Record 32 of Set 2 | grindavik
# Processing Record 33 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 2 | saint johnsbury
# Processing Record 35 of Set 2 | bahia honda
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | moussoro
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | himatnagar
# Processing Record 42 of Set 2 | kavaratti
# Processing Record 43 of Set 2 | kumba
# Processing Record 44 of Set 2 | fortuna
# Processing Record 45 of Set 2 | tiznit
# Processing Record 46 of Set 2 | kahului
# Processing Record 47 of Set 2 | wolbrom
# Processing Record 48 of Set 2 | jijiga
# Processing Record 49 of Set 2 | lavrentiya
# Processing Record 50 of Set 2 | talnakh
# Processing Record 1 of Set 3 | naze
# Processing Record 2 of Set 3 | saint george
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | sunbury
# Processing Record 5 of Set 3 | hegang
# Processing Record 6 of Set 3 | berlevag
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | burica
# City not found. Skipping...
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | cozumel
# Processing Record 16 of Set 3 | kidal
# Processing Record 17 of Set 3 | fairbanks
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | saint-francois
# Processing Record 20 of Set 3 | te anau
# Processing Record 21 of Set 3 | albany
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | ahipara
# Processing Record 24 of Set 3 | itigi
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | cuenca
# Processing Record 27 of Set 3 | san vicente
# Processing Record 28 of Set 3 | port-gentil
# Processing Record 29 of Set 3 | greystones
# Processing Record 30 of Set 3 | hammerfest
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | paredon
# Processing Record 33 of Set 3 | codrington
# Processing Record 34 of Set 3 | kawalu
# Processing Record 35 of Set 3 | tura
# Processing Record 36 of Set 3 | havre-saint-pierre
# Processing Record 37 of Set 3 | sijunjung
# Processing Record 38 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 3 | voh
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | luganville
# Processing Record 44 of Set 3 | fukue
# Processing Record 45 of Set 3 | qui nhon
# Processing Record 46 of Set 3 | saint-augustin
# Processing Record 47 of Set 3 | panagar
# Processing Record 48 of Set 3 | nam som
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | touros
# Processing Record 1 of Set 4 | suez
# Processing Record 2 of Set 4 | teguldet
# Processing Record 3 of Set 4 | vila
# Processing Record 4 of Set 4 | codroipo
# Processing Record 5 of Set 4 | muisne
# Processing Record 6 of Set 4 | ishim
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | manmad
# Processing Record 9 of Set 4 | bilibino
# Processing Record 10 of Set 4 | faya
# Processing Record 11 of Set 4 | sfantu gheorghe
# Processing Record 12 of Set 4 | vaini
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | raudeberg
# Processing Record 15 of Set 4 | arraial do cabo
# Processing Record 16 of Set 4 | severo-kurilsk
# Processing Record 17 of Set 4 | carnarvon
# Processing Record 18 of Set 4 | george
# Processing Record 19 of Set 4 | avera
# Processing Record 20 of Set 4 | korce
# Processing Record 21 of Set 4 | olafsvik
# Processing Record 22 of Set 4 | tigil
# Processing Record 23 of Set 4 | cerrito
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | hudson bay
# Processing Record 26 of Set 4 | cockburn town
# Processing Record 27 of Set 4 | barrow
# Processing Record 28 of Set 4 | nikolskoye
# Processing Record 29 of Set 4 | guanica
# Processing Record 30 of Set 4 | hami
# Processing Record 31 of Set 4 | sao geraldo do araguaia
# Processing Record 32 of Set 4 | boa vista
# Processing Record 33 of Set 4 | alofi
# Processing Record 34 of Set 4 | smiltene
# Processing Record 35 of Set 4 | moron de la frontera
# Processing Record 36 of Set 4 | chalus
# Processing Record 37 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 4 | la crosse
# Processing Record 39 of Set 4 | pizarro
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 4 | uyovu
# Processing Record 42 of Set 4 | tchollire
# Processing Record 43 of Set 4 | monster
# Processing Record 44 of Set 4 | castlecomer
# Processing Record 45 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4 | tecolutla
# Processing Record 47 of Set 4 | nantucket
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | mayor pablo lagerenza
# Processing Record 50 of Set 4 | dingle
# Processing Record 1 of Set 5 | goderich
# Processing Record 2 of Set 5 | kachhwa
# Processing Record 3 of Set 5 | taree
# Processing Record 4 of Set 5 | tutoia
# Processing Record 5 of Set 5 | cadillac
# Processing Record 6 of Set 5 | college
# Processing Record 7 of Set 5 | arlit
# Processing Record 8 of Set 5 | hambantota
# Processing Record 9 of Set 5 | raurkela
# City not found. Skipping...
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | tual
# Processing Record 12 of Set 5 | russell
# Processing Record 13 of Set 5 | altamira
# Processing Record 14 of Set 5 | port lincoln
# Processing Record 15 of Set 5 | viraganur
# Processing Record 16 of Set 5 | kaeo
# Processing Record 17 of Set 5 | tezu
# Processing Record 18 of Set 5 | gerash
# Processing Record 19 of Set 5 | tamandare
# Processing Record 20 of Set 5 | trairi
# Processing Record 21 of Set 5 | pangnirtung
# Processing Record 22 of Set 5 | klaksvik
# Processing Record 23 of Set 5 | san andres
# Processing Record 24 of Set 5 | lillesand
# Processing Record 25 of Set 5 | lokosovo
# Processing Record 26 of Set 5 | naron
# Processing Record 27 of Set 5 | asau
# Processing Record 28 of Set 5 | machali
# Processing Record 29 of Set 5 | nizhneangarsk
# Processing Record 30 of Set 5 | ninghai
# Processing Record 31 of Set 5 | pisco
# Processing Record 32 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | ancud
# Processing Record 35 of Set 5 | pangoa
# Processing Record 36 of Set 5 | mwanza
# Processing Record 37 of Set 5 | nove mesto na morave
# Processing Record 38 of Set 5 | laguna
# Processing Record 39 of Set 5 | georgetown
# Processing Record 40 of Set 5 | longyearbyen
# Processing Record 41 of Set 5 | hualmay
# Processing Record 42 of Set 5 | litovko
# Processing Record 43 of Set 5 | sakakah
# Processing Record 44 of Set 5 | lazaro cardenas
# Processing Record 45 of Set 5 | victoria
# Processing Record 46 of Set 5 | orotukan
# Processing Record 47 of Set 5 | vagur
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | gamba
# Processing Record 50 of Set 5 | nuuk
# Processing Record 1 of Set 6 | fort-shevchenko
# Processing Record 2 of Set 6 | hearst
# Processing Record 3 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 4 of Set 6 | provideniya
# Processing Record 5 of Set 6 | soledade
# Processing Record 6 of Set 6 | liliongan
# Processing Record 7 of Set 6 | umm lajj
# Processing Record 8 of Set 6 | himora
# City not found. Skipping...
# Processing Record 9 of Set 6 | birao
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | canatlan
# Processing Record 12 of Set 6 | mgandu
# Processing Record 13 of Set 6 | tiarei
# Processing Record 14 of Set 6 | lagoa
# Processing Record 15 of Set 6 | kruisfontein
# Processing Record 16 of Set 6 | shushtar
# Processing Record 17 of Set 6 | zhigansk
# Processing Record 18 of Set 6 | coquimbo
# Processing Record 19 of Set 6 | uarini
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | pringsewu
# Processing Record 22 of Set 6 | hamilton
# Processing Record 23 of Set 6 | basse
# Processing Record 24 of Set 6 | ken caryl
# Processing Record 25 of Set 6 | faanui
# Processing Record 26 of Set 6 | rio grande
# Processing Record 27 of Set 6 | kang
# Processing Record 28 of Set 6 | lodeynoye pole
# Processing Record 29 of Set 6 | ostrovnoy
# Processing Record 30 of Set 6 | sale
# Processing Record 31 of Set 6 | hilo
# Processing Record 32 of Set 6 | sigli
# Processing Record 33 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 6 | portland
# Processing Record 35 of Set 6 | pemangkat
# Processing Record 36 of Set 6 | bethel
# Processing Record 37 of Set 6 | yumen
# Processing Record 38 of Set 6 | yamada
# Processing Record 39 of Set 6 | ocampo
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | vanimo
# Processing Record 42 of Set 6 | portpatrick
# City not found. Skipping...
# Processing Record 43 of Set 6 | yasothon
# Processing Record 44 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 6 | kijang
# Processing Record 46 of Set 6 | rincon
# Processing Record 47 of Set 6 | ikom
# Processing Record 48 of Set 6 | tazovskiy
# Processing Record 49 of Set 6 | kirakira
# Processing Record 50 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 7 | gat
# Processing Record 2 of Set 7 | dali
# Processing Record 3 of Set 7 | abu dhabi
# Processing Record 4 of Set 7 | bambanglipuro
# Processing Record 5 of Set 7 | evreux
# Processing Record 6 of Set 7 | kongolo
# Processing Record 7 of Set 7 | leningradskiy
# Processing Record 8 of Set 7 | eyl
# Processing Record 9 of Set 7 | crib point
# Processing Record 10 of Set 7 | pasni
# Processing Record 11 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 7 | alta floresta
# Processing Record 13 of Set 7 | khani
# Processing Record 14 of Set 7 | panama city
# Processing Record 15 of Set 7 | rengali
# Processing Record 16 of Set 7 | lasa
# Processing Record 17 of Set 7 | tomatlan
# Processing Record 18 of Set 7 | kayerkan
# Processing Record 19 of Set 7 | pedasi
# Processing Record 20 of Set 7 | samana
# Processing Record 21 of Set 7 | krasnyy kut
# Processing Record 22 of Set 7 | porto novo
# Processing Record 23 of Set 7 | sainte-agathe-des-monts
# Processing Record 24 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 7 | fairmont
# Processing Record 26 of Set 7 | nome
# Processing Record 27 of Set 7 | maine-soroa
# Processing Record 28 of Set 7 | etawah
# Processing Record 29 of Set 7 | araouane
# Processing Record 30 of Set 7 | mbala
# Processing Record 31 of Set 7 | tucumcari
# Processing Record 32 of Set 7 | mana
# Processing Record 33 of Set 7 | clyde river
# Processing Record 34 of Set 7 | nioro
# Processing Record 35 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 7 | katsuura
# Processing Record 37 of Set 7 | karlstad
# Processing Record 38 of Set 7 | chimbote
# Processing Record 39 of Set 7 | bagasara
# City not found. Skipping...
# Processing Record 40 of Set 7 | sola
# Processing Record 41 of Set 7 | cafarnaum
# Processing Record 42 of Set 7 | krasnoborsk
# Processing Record 43 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 44 of Set 7 | paamiut
# Processing Record 45 of Set 7 | praya
# Processing Record 46 of Set 7 | utete
# Processing Record 47 of Set 7 | hobyo
# Processing Record 48 of Set 7 | shenjiamen
# Processing Record 49 of Set 7 | keningau
# Processing Record 50 of Set 7 | amazar
# Processing Record 1 of Set 8 | sitka
# Processing Record 2 of Set 8 | california city
# Processing Record 3 of Set 8 | castro
# Processing Record 4 of Set 8 | kawhia
# Processing Record 5 of Set 8 | caluquembe
# Processing Record 6 of Set 8 | kudahuvadhoo
# Processing Record 7 of Set 8 | dikson
# Processing Record 8 of Set 8 | san carlos de bariloche
# Processing Record 9 of Set 8 | coihaique
# Processing Record 10 of Set 8 | sibu
# Processing Record 11 of Set 8 | farah
# Processing Record 12 of Set 8 | richards bay
# Processing Record 13 of Set 8 | port augusta
# Processing Record 14 of Set 8 | storforshei
# Processing Record 15 of Set 8 | juneau
# Processing Record 16 of Set 8 | lampazos de naranjo
# Processing Record 17 of Set 8 | itiuba
# Processing Record 18 of Set 8 | henties bay
# Processing Record 19 of Set 8 | cabedelo
# Processing Record 20 of Set 8 | san rafael
# Processing Record 21 of Set 8 | hailar
# Processing Record 22 of Set 8 | killybegs
# Processing Record 23 of Set 8 | okhotsk
# Processing Record 24 of Set 8 | ziro
# Processing Record 25 of Set 8 | north platte
# Processing Record 26 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 8 | arman
# Processing Record 28 of Set 8 | pavlodar
# Processing Record 29 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 8 | manuk mangkaw
# Processing Record 31 of Set 8 | ashcroft
# Processing Record 32 of Set 8 | rabo de peixe
# Processing Record 33 of Set 8 | mopipi
# Processing Record 34 of Set 8 | miyako
# Processing Record 35 of Set 8 | galegos
# Processing Record 36 of Set 8 | kissidougou
# Processing Record 37 of Set 8 | ilam
# Processing Record 38 of Set 8 | dalvik
# Processing Record 39 of Set 8 | kichera
# Processing Record 40 of Set 8 | suoyarvi
# Processing Record 41 of Set 8 | inuvik
# Processing Record 42 of Set 8 | coracora
# Processing Record 43 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 44 of Set 8 | tromso
# Processing Record 45 of Set 8 | sao joao da barra
# Processing Record 46 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 8 | maracas
# Processing Record 48 of Set 8 | villarrica
# Processing Record 49 of Set 8 | jacareacanga
# Processing Record 50 of Set 8 | malacky
# Processing Record 1 of Set 9 | moba
# Processing Record 2 of Set 9 | coahuayana
# Processing Record 3 of Set 9 | kabare
# Processing Record 4 of Set 9 | berdigestyakh
# Processing Record 5 of Set 9 | ekibastuz
# Processing Record 6 of Set 9 | wajima
# Processing Record 7 of Set 9 | walvis bay
# Processing Record 8 of Set 9 | margate
# Processing Record 9 of Set 9 | agadir
# Processing Record 10 of Set 9 | tarko-sale
# Processing Record 11 of Set 9 | kavieng
# Processing Record 12 of Set 9 | yar-sale
# Processing Record 13 of Set 9 | makaha
# Processing Record 14 of Set 9 | nenjiang
# Processing Record 15 of Set 9 | boguchany
# Processing Record 16 of Set 9 | mutum
# Processing Record 17 of Set 9 | korla
# Processing Record 18 of Set 9 | kapit
# Processing Record 19 of Set 9 | ballina
# Processing Record 20 of Set 9 | trelew
# Processing Record 21 of Set 9 | slevik
# City not found. Skipping...
# Processing Record 22 of Set 9 | tabuelan
# Processing Record 23 of Set 9 | terrace bay
# Processing Record 24 of Set 9 | kirishi
# Processing Record 25 of Set 9 | vostok
# Processing Record 26 of Set 9 | villamontes
# Processing Record 27 of Set 9 | arkhangelsk
# Processing Record 28 of Set 9 | lang suan
# Processing Record 29 of Set 9 | kiknur
# Processing Record 30 of Set 9 | darhan
# Processing Record 31 of Set 9 | constitucion
# Processing Record 32 of Set 9 | bathsheba
# Processing Record 33 of Set 9 | biltine
# Processing Record 34 of Set 9 | ales
# Processing Record 35 of Set 9 | redlands
# Processing Record 36 of Set 9 | mount gambier
# Processing Record 37 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 9 | otavi
# Processing Record 39 of Set 9 | fengxian
# Processing Record 40 of Set 9 | pangody
# Processing Record 41 of Set 9 | wanning
# Processing Record 42 of Set 9 | tilichiki
# Processing Record 43 of Set 9 | mbandaka
# Processing Record 44 of Set 9 | srednekolymsk
# Processing Record 45 of Set 9 | dauriya
# Processing Record 46 of Set 9 | chatsu
# City not found. Skipping...
# Processing Record 47 of Set 9 | golden
# Processing Record 48 of Set 9 | chachapoyas
# Processing Record 49 of Set 9 | kudat
# Processing Record 50 of Set 9 | lorengau
# Processing Record 1 of Set 10 | tabou
# Processing Record 2 of Set 10 | sept-iles
# Processing Record 3 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 4 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 10 | tocopilla
# Processing Record 6 of Set 10 | yeltsovka
# City not found. Skipping...
# Processing Record 7 of Set 10 | krasnyy chikoy
# Processing Record 8 of Set 10 | salinas
# Processing Record 9 of Set 10 | kumher
# Processing Record 10 of Set 10 | manjakandriana
# Processing Record 11 of Set 10 | kefamenanu
# Processing Record 12 of Set 10 | taksimo
# Processing Record 13 of Set 10 | tommot
# Processing Record 14 of Set 10 | tarata
# Processing Record 15 of Set 10 | geraldton
# Processing Record 16 of Set 10 | dalbandin
# Processing Record 17 of Set 10 | flin flon
# Processing Record 18 of Set 10 | moron
# Processing Record 19 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 20 of Set 10 | xudat
# Processing Record 21 of Set 10 | opunake
# Processing Record 22 of Set 10 | beruni
# City not found. Skipping...
# Processing Record 23 of Set 10 | shimoda
# Processing Record 24 of Set 10 | alice springs
# Processing Record 25 of Set 10 | deputatskiy
# Processing Record 26 of Set 10 | staryy nadym
# Processing Record 27 of Set 10 | karla
# Processing Record 28 of Set 10 | padang
# Processing Record 29 of Set 10 | ust-nera
# Processing Record 30 of Set 10 | banjar
# Processing Record 31 of Set 10 | rundu
# Processing Record 32 of Set 10 | mareeba
# Processing Record 33 of Set 10 | sobolevo
# Processing Record 34 of Set 10 | tuatapere
# Processing Record 35 of Set 10 | waingapu
# Processing Record 36 of Set 10 | debre tabor
# Processing Record 37 of Set 10 | liverpool
# Processing Record 38 of Set 10 | oussouye
# Processing Record 39 of Set 10 | aberdeen
# Processing Record 40 of Set 10 | itarema
# Processing Record 41 of Set 10 | taltal
# Processing Record 42 of Set 10 | labrea
# Processing Record 43 of Set 10 | taiyuan
# Processing Record 44 of Set 10 | satao
# Processing Record 45 of Set 10 | makakilo city
# Processing Record 46 of Set 10 | barranca
# Processing Record 47 of Set 10 | nizhniy kuranakh
# Processing Record 48 of Set 10 | nizhnevartovsk
# Processing Record 49 of Set 10 | ussel
# Processing Record 50 of Set 10 | sebinkarahisar
# Processing Record 1 of Set 11 | takoradi
# Processing Record 2 of Set 11 | ixtapa
# Processing Record 3 of Set 11 | boksitogorsk
# Processing Record 4 of Set 11 | buenaventura
# Processing Record 5 of Set 11 | durango
# Processing Record 6 of Set 11 | north myrtle beach
# Processing Record 7 of Set 11 | saint anthony
# Processing Record 8 of Set 11 | ankara
# Processing Record 9 of Set 11 | marawi
# Processing Record 10 of Set 11 | huarmey
# Processing Record 11 of Set 11 | great yarmouth
# Processing Record 12 of Set 11 | kroya
# Processing Record 13 of Set 11 | namie
# Processing Record 14 of Set 11 | solnechnyy
# Processing Record 15 of Set 11 | tlahualilo
# City not found. Skipping...
# Processing Record 16 of Set 11 | bulancak
# Processing Record 17 of Set 11 | lermontovka
# Processing Record 18 of Set 11 | ramgarh
# Processing Record 19 of Set 11 | saquarema
# Processing Record 20 of Set 11 | general macarthur
# Processing Record 21 of Set 11 | narsaq
# Processing Record 22 of Set 11 | kemijarvi
# Processing Record 23 of Set 11 | sao filipe
# Processing Record 24 of Set 11 | antofagasta
# Processing Record 25 of Set 11 | salatiga
# Processing Record 26 of Set 11 | noshiro
# Processing Record 27 of Set 11 | neiafu
# Processing Record 28 of Set 11 | hasaki
# Processing Record 29 of Set 11 | bocaiuva
# Processing Record 30 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 11 | fuyu
# Processing Record 32 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 33 of Set 11 | puerto del rosario
# Processing Record 34 of Set 11 | yeppoon
# Processing Record 35 of Set 11 | fergus falls
# Processing Record 36 of Set 11 | talaya
# Processing Record 37 of Set 11 | port hedland
# Processing Record 38 of Set 11 | asahikawa
# Processing Record 39 of Set 11 | little current
# Processing Record 40 of Set 11 | hasanabad
# Processing Record 41 of Set 11 | zemetchino
# Processing Record 42 of Set 11 | tagusao
# Processing Record 43 of Set 11 | sibolga
# Processing Record 44 of Set 11 | suarez
# Processing Record 45 of Set 11 | harper
# Processing Record 46 of Set 11 | tupanatinga
# Processing Record 47 of Set 11 | brae
# Processing Record 48 of Set 11 | alyangula
# Processing Record 49 of Set 11 | sao roque
# Processing Record 50 of Set 11 | fuling
# Processing Record 1 of Set 12 | salta
# Processing Record 2 of Set 12 | doboj
# Processing Record 3 of Set 12 | kieta
# Processing Record 4 of Set 12 | kisesa
# Processing Record 5 of Set 12 | palmas
# Processing Record 6 of Set 12 | ilulissat
# Processing Record 7 of Set 12 | sioux falls
# Processing Record 8 of Set 12 | ust-kuyga
# Processing Record 9 of Set 12 | celestun
# Processing Record 10 of Set 12 | tateyama
# Processing Record 11 of Set 12 | temoac
# Processing Record 12 of Set 12 | san joaquin
# Processing Record 13 of Set 12 | capreol
# Processing Record 14 of Set 12 | butembo
# Processing Record 15 of Set 12 | viedma
# Processing Record 16 of Set 12 | vezirkopru
# Processing Record 17 of Set 12 | namtsy
# Processing Record 18 of Set 12 | pouembout
# Processing Record 19 of Set 12 | matadi
# Processing Record 20 of Set 12 | anta
# Processing Record 21 of Set 12 | shingu
# Processing Record 22 of Set 12 | zaranj
# Processing Record 23 of Set 12 | mto wa mbu
# Processing Record 24 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 12 | belluno
# Processing Record 26 of Set 12 | quatre cocos
# Processing Record 27 of Set 12 | maloy
# Processing Record 28 of Set 12 | sudak
# Processing Record 29 of Set 12 | vila franca do campo
# Processing Record 30 of Set 12 | stara vyzhivka
# Processing Record 31 of Set 12 | berezovyy
# Processing Record 32 of Set 12 | les ponts-de-ce
# Processing Record 33 of Set 12 | lufilufi
# Processing Record 34 of Set 12 | mwinilunga
# Processing Record 35 of Set 12 | dehloran
# Processing Record 36 of Set 12 | bilma
# Processing Record 37 of Set 12 | issoudun
# Processing Record 38 of Set 12 | burkhala
# City not found. Skipping...
# Processing Record 39 of Set 12 | dunedin
# Processing Record 40 of Set 12 | pampas
# Processing Record 41 of Set 12 | camopi
# Processing Record 42 of Set 12 | kasempa
# Processing Record 43 of Set 12 | washington
# Processing Record 44 of Set 12 | santa vitoria do palmar
# Processing Record 45 of Set 12 | vestmannaeyjar
# Processing Record 46 of Set 12 | jian
# Processing Record 47 of Set 12 | guiren
# Processing Record 48 of Set 12 | novopskov
# Processing Record 49 of Set 12 | kayunga
# Processing Record 50 of Set 12 | mikhaylovka
# Processing Record 1 of Set 13 | tautira
# Processing Record 2 of Set 13 | zeya
# Processing Record 3 of Set 13 | amarillo
# Processing Record 4 of Set 13 | palana
# Processing Record 5 of Set 13 | bow island
# Processing Record 6 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 13 | mitu
# Processing Record 8 of Set 13 | anchorage
# Processing Record 9 of Set 13 | mountain home
# Processing Record 10 of Set 13 | urozhayne
# City not found. Skipping...
# Processing Record 11 of Set 13 | mount isa
# Processing Record 12 of Set 13 | saint-pierre
# Processing Record 13 of Set 13 | klyuchi
# Processing Record 14 of Set 13 | axim
# Processing Record 15 of Set 13 | nouadhibou
# Processing Record 16 of Set 13 | moerai
# Processing Record 17 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 13 | roswell
# Processing Record 19 of Set 13 | itacare
# Processing Record 20 of Set 13 | kalmunai
# Processing Record 21 of Set 13 | crotone
# Processing Record 22 of Set 13 | torbay
# Processing Record 23 of Set 13 | hirara
# Processing Record 24 of Set 13 | christchurch
# Processing Record 25 of Set 13 | manakara
# Processing Record 26 of Set 13 | muroto
# Processing Record 27 of Set 13 | vao
# Processing Record 28 of Set 13 | fagersta
# Processing Record 29 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 13 | arrecife
# Processing Record 31 of Set 13 | amapa
# Processing Record 32 of Set 13 | revadanda
# Processing Record 33 of Set 13 | srivardhan
# Processing Record 34 of Set 13 | izvestkovyy
# Processing Record 35 of Set 13 | nueve de julio
# Processing Record 36 of Set 13 | gambela
# Processing Record 37 of Set 13 | lumberton
# Processing Record 38 of Set 13 | ust-koksa
# Processing Record 39 of Set 13 | daule
# Processing Record 40 of Set 13 | sharjah
# Processing Record 41 of Set 13 | great bend
# Processing Record 42 of Set 13 | sambava
# Processing Record 43 of Set 13 | wewak
# Processing Record 44 of Set 13 | erenhot
# Processing Record 45 of Set 13 | jeremie
# Processing Record 46 of Set 13 | jijiang
# Processing Record 47 of Set 13 | roma
# Processing Record 48 of Set 13 | zanjan
# Processing Record 49 of Set 13 | tangjiazhuang
# Processing Record 50 of Set 13 | luanda
# Processing Record 1 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 14 | wladyslawowo
# Processing Record 3 of Set 14 | lincoln
# Processing Record 4 of Set 14 | buala
# Processing Record 5 of Set 14 | mahibadhoo
# Processing Record 6 of Set 14 | santa rosa
# Processing Record 7 of Set 14 | praia da vitoria
# Processing Record 8 of Set 14 | reconquista
# Processing Record 9 of Set 14 | caucaia
# Processing Record 10 of Set 14 | peleduy
# Processing Record 11 of Set 14 | orocue
# Processing Record 12 of Set 14 | san ramon
# Processing Record 13 of Set 14 | prainha
# Processing Record 14 of Set 14 | hanmer springs
# Processing Record 15 of Set 14 | villa union
# Processing Record 16 of Set 14 | mehamn
# Processing Record 17 of Set 14 | otjiwarongo
# Processing Record 18 of Set 14 | goundam
# Processing Record 19 of Set 14 | grand-santi
# Processing Record 20 of Set 14 | ostersund
# Processing Record 21 of Set 14 | cody
# Processing Record 22 of Set 14 | vilyuysk
# Processing Record 23 of Set 14 | sechura
# Processing Record 24 of Set 14 | mae hong son
# Processing Record 25 of Set 14 | kayes
# Processing Record 26 of Set 14 | odweyne
# Processing Record 27 of Set 14 | palauig
# Processing Record 28 of Set 14 | melilla
# Processing Record 29 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 14 | sarakhs
# Processing Record 31 of Set 14 | keuruu
# Processing Record 32 of Set 14 | beausejour
# Processing Record 33 of Set 14 | coolum beach
# Processing Record 34 of Set 14 | yurgamysh
# Processing Record 35 of Set 14 | montes altos
# Processing Record 36 of Set 14 | narragansett
# Processing Record 37 of Set 14 | awbari
# Processing Record 38 of Set 14 | mackay
# Processing Record 39 of Set 14 | turkistan
# Processing Record 40 of Set 14 | turukhansk
# City not found. Skipping...
# Processing Record 41 of Set 14 | rawson
# Processing Record 42 of Set 14 | delta del tigre
# Processing Record 43 of Set 14 | zhezkazgan
# Processing Record 44 of Set 14 | zyryanka
# Processing Record 45 of Set 14 | healdsburg
# Processing Record 46 of Set 14 | port blair
# Processing Record 47 of Set 14 | midsalip
# Processing Record 48 of Set 14 | les herbiers
# Processing Record 49 of Set 14 | seymchan
# Processing Record 50 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 15 | vuktyl
# Processing Record 2 of Set 15 | husavik
# Processing Record 3 of Set 15 | kigonsera
# Processing Record 4 of Set 15 | yomou
# Processing Record 5 of Set 15 | sao paulo de olivenca
# Processing Record 6 of Set 15 | felanitx
# Processing Record 7 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 8 of Set 15 | lompoc
# Processing Record 9 of Set 15 | ilhabela
# Processing Record 10 of Set 15 | port hardy
# Processing Record 11 of Set 15 | chibombo
# Processing Record 12 of Set 15 | council bluffs
# Processing Record 13 of Set 15 | saint-leu
# Processing Record 14 of Set 15 | xiamen
# Processing Record 15 of Set 15 | karpuninskiy
# City not found. Skipping...
# Processing Record 16 of Set 15 | ribe
# Processing Record 17 of Set 15 | dingzhou
# Processing Record 18 of Set 15 | riberalta
# Processing Record 19 of Set 15 | thinadhoo
# Processing Record 20 of Set 15 | san juan
# Processing Record 21 of Set 15 | unye
# City not found. Skipping...
# Processing Record 22 of Set 15 | treinta y tres
# Processing Record 23 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 15 | kamen-na-obi
# Processing Record 25 of Set 15 | champerico
# Processing Record 26 of Set 15 | prince rupert
# Processing Record 27 of Set 15 | san jose
# Processing Record 28 of Set 15 | indre arna
# Processing Record 29 of Set 15 | tessalit
# Processing Record 30 of Set 15 | rocha
# Processing Record 31 of Set 15 | san quintin
# Processing Record 32 of Set 15 | hovin
# Processing Record 33 of Set 15 | chissamba
# Processing Record 34 of Set 15 | karratha
# City not found. Skipping...
# Processing Record 35 of Set 15 | ulaangom
# Processing Record 36 of Set 15 | bhadasar
# Processing Record 37 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 15 | shelburne
# Processing Record 39 of Set 15 | comodoro rivadavia
# Processing Record 40 of Set 15 | markova
# Processing Record 41 of Set 15 | santiago
# Processing Record 42 of Set 15 | sinazongwe
# Processing Record 43 of Set 15 | erzin
# Processing Record 44 of Set 15 | bataipora
# Processing Record 45 of Set 15 | morant bay
# Processing Record 46 of Set 15 | ferme-neuve
# Processing Record 47 of Set 15 | bubaque
# Processing Record 48 of Set 15 | shache
# Processing Record 49 of Set 15 | jacmel
# Processing Record 50 of Set 15 | camacha
# Processing Record 1 of Set 16 | diveyevo
# Processing Record 2 of Set 16 | birjand
# Processing Record 3 of Set 16 | langsa
# Processing Record 4 of Set 16 | svetlyy
# Processing Record 5 of Set 16 | dzhebariki-khaya
# Processing Record 6 of Set 16 | naryan-mar
# Processing Record 7 of Set 16 | cap malheureux
# Processing Record 8 of Set 16 | thio
# Processing Record 9 of Set 16 | pyapon
# Processing Record 10 of Set 16 | waddan
# Processing Record 11 of Set 16 | igunga
# Processing Record 12 of Set 16 | huesca
# Processing Record 13 of Set 16 | manaus
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data

# %%
len(city_data)

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bluff -46.6000  168.3333     44.80        73           2
# 1        Atuona  -9.8000 -139.0333     77.59        77          14
# 2       Ushuaia -54.8000  -68.3000     26.69        97          94
# 3         Kapaa  22.0752 -159.3190     82.38        76           7
# 4    Viransehir  37.2353   39.7631     87.67        18           0
# 5  Saint-Joseph -21.3667   55.6167     70.21        79          25
# 6   Yellowknife  62.4560 -114.3525     63.12        63          20
# 7       Garissa  -0.4536   39.6401     73.53        72          17
# 8      Cherskiy  68.7500  161.3000     57.06        43          23
# 9      Tasiilaq  65.6145  -37.6368     33.96        82          61
#
#    Wind Speed Country                 Date
# 0        4.59      NZ  2022-07-23 05:01:54
# 1       16.11      PF  2022-07-23 05:01:48
# 2        3.27      AR  2022-07-23 05:00:40
# 3        1.99      US  2022-07-23 04:56:16
# 4        3.04      TR  2022-07-23 05:05:07
# 5       14.54      RE  2022-07-23 05:05:07
# 6        8.05      CA  2022-07-23 04:58:56
# 7       17.52      KE  2022-07-23 05:05:08
# 8        3.91      RU  2022-07-23 04:58:55
# 9        8.23      GL  2022-07-23 05:03:14

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("WeatherPy_challenge.csv", index_label="City ID" )
