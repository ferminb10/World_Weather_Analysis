# %%
#Import Dependencies
from citipy import citipy
import random
import numpy as np
import timeit
import pandas as pd
import matplotlib.pyplot as plt

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lats_lngs)

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
#for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
   # if (i % 50 == 0 and i >= 50):
       # set_count += 1
       # record_count = 1

    # Create endpoint URL with each city.
   # city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard, uncomment just in case you need to add a timestamp
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          'Weather Description': city_weather_description})
                          #"Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 3 of Set 1 | sao domingos
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | port macquarie
# Processing Record 6 of Set 1 | port blair
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 1 | vanimo
# Processing Record 11 of Set 1 | freeport
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | mayskiy
# Processing Record 14 of Set 1 | egvekinot
# Processing Record 15 of Set 1 | guerrero negro
# Processing Record 16 of Set 1 | thunder bay
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | srednekolymsk
# Processing Record 19 of Set 1 | piacabucu
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | porto velho
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 1 | pacific grove
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | adrar
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | labuhan
# Processing Record 30 of Set 1 | celestun
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | auki
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | mvomero
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | usinsk
# Processing Record 44 of Set 1 | lodja
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | malatya
# Processing Record 47 of Set 1 | lagoa
# Processing Record 48 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | alice springs
# Processing Record 50 of Set 1 | berbera
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | vestmannaeyjar
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 2 | sibolga
# Processing Record 10 of Set 2 | constitucion
# Processing Record 11 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 2 | mizdah
# Processing Record 13 of Set 2 | gizo
# Processing Record 14 of Set 2 | norman wells
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | kirillov
# Processing Record 17 of Set 2 | beloha
# Processing Record 18 of Set 2 | kimparana
# Processing Record 19 of Set 2 | pisco
# Processing Record 20 of Set 2 | izmir
# Processing Record 21 of Set 2 | rincon
# Processing Record 22 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | kudahuvadhoo
# Processing Record 25 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 2 | bethel
# Processing Record 27 of Set 2 | menton
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | cedar city
# Processing Record 30 of Set 2 | tarko-sale
# Processing Record 31 of Set 2 | vestmanna
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | mareeba
# Processing Record 34 of Set 2 | asau
# Processing Record 35 of Set 2 | port hardy
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | yulara
# Processing Record 38 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 2 | esperance
# Processing Record 41 of Set 2 | gillette
# Processing Record 42 of Set 2 | bontang
# Processing Record 43 of Set 2 | kalmunai
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | ponta delgada
# Processing Record 47 of Set 2 | minab
# Processing Record 48 of Set 2 | byron bay
# Processing Record 49 of Set 2 | riverton
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 3 | clyde river
# Processing Record 3 of Set 3 | polovinnoye
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | hilo
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | bengkulu
# Processing Record 9 of Set 3 | poum
# Processing Record 10 of Set 3 | vila franca do campo
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | turbat
# Processing Record 13 of Set 3 | tubuala
# Processing Record 14 of Set 3 | lasa
# Processing Record 15 of Set 3 | chau doc
# Processing Record 16 of Set 3 | yumen
# Processing Record 17 of Set 3 | agadez
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | avera
# Processing Record 20 of Set 3 | vila velha
# Processing Record 21 of Set 3 | hofn
# Processing Record 22 of Set 3 | nuuk
# Processing Record 23 of Set 3 | antofagasta
# Processing Record 24 of Set 3 | kieta
# Processing Record 25 of Set 3 | fortuna foothills
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | talnakh
# Processing Record 29 of Set 3 | dagua
# Processing Record 30 of Set 3 | touros
# Processing Record 31 of Set 3 | xining
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | caconda
# Processing Record 34 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 3 | mount gambier
# Processing Record 38 of Set 3 | saint-philippe
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | mollendo
# Processing Record 41 of Set 3 | folkestone
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | elesbao veloso
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | vostok
# Processing Record 46 of Set 3 | provideniya
# Processing Record 47 of Set 3 | sabya
# Processing Record 48 of Set 3 | charters towers
# Processing Record 49 of Set 3 | stornoway
# Processing Record 50 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 4 | taltal
# Processing Record 2 of Set 4 | honiara
# Processing Record 3 of Set 4 | cap malheureux
# Processing Record 4 of Set 4 | kanashevo
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | portree
# Processing Record 7 of Set 4 | hermanus
# Processing Record 8 of Set 4 | maningrida
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | naze
# Processing Record 11 of Set 4 | elizabeth city
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | havoysund
# Processing Record 14 of Set 4 | namie
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | batticaloa
# Processing Record 17 of Set 4 | krasnoselkup
# Processing Record 18 of Set 4 | cabinda
# Processing Record 19 of Set 4 | sioux lookout
# Processing Record 20 of Set 4 | biak
# Processing Record 21 of Set 4 | camacha
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 4 | vadso
# Processing Record 25 of Set 4 | los llanos de aridane
# Processing Record 26 of Set 4 | barrow
# Processing Record 27 of Set 4 | mehamn
# Processing Record 28 of Set 4 | loubomo
# Processing Record 29 of Set 4 | portland
# Processing Record 30 of Set 4 | lompoc
# Processing Record 31 of Set 4 | kupang
# Processing Record 32 of Set 4 | codajas
# Processing Record 33 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 34 of Set 4 | avarua
# Processing Record 35 of Set 4 | husavik
# Processing Record 36 of Set 4 | necochea
# Processing Record 37 of Set 4 | brenham
# Processing Record 38 of Set 4 | hohhot
# Processing Record 39 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 4 | berlevag
# Processing Record 41 of Set 4 | saint george
# Processing Record 42 of Set 4 | zemio
# Processing Record 43 of Set 4 | bud
# Processing Record 44 of Set 4 | thomaston
# Processing Record 45 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 4 | rio gallegos
# Processing Record 47 of Set 4 | pitimbu
# Processing Record 48 of Set 4 | pokrovsk
# Processing Record 49 of Set 4 | hobyo
# Processing Record 50 of Set 4 | kismayo
# Processing Record 1 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 5 | douglas
# Processing Record 3 of Set 5 | uni
# Processing Record 4 of Set 5 | andenes
# Processing Record 5 of Set 5 | jieshi
# Processing Record 6 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 5 | atar
# Processing Record 8 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 5 | verkhoyansk
# Processing Record 10 of Set 5 | namibe
# Processing Record 11 of Set 5 | sirjan
# Processing Record 12 of Set 5 | dunedin
# Processing Record 13 of Set 5 | nikolskoye
# Processing Record 14 of Set 5 | shizuishan
# Processing Record 15 of Set 5 | kamaishi
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | saint-paul
# Processing Record 18 of Set 5 | port arthur
# Processing Record 19 of Set 5 | mirnyy
# Processing Record 20 of Set 5 | stokmarknes
# Processing Record 21 of Set 5 | medea
# Processing Record 22 of Set 5 | camana
# Processing Record 23 of Set 5 | aswan
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | lata
# Processing Record 26 of Set 5 | quatre cocos
# Processing Record 27 of Set 5 | bartica
# Processing Record 28 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 5 | ancud
# Processing Record 30 of Set 5 | san andres del rabanedo
# Processing Record 31 of Set 5 | tessalit
# Processing Record 32 of Set 5 | laizhou
# Processing Record 33 of Set 5 | sorland
# Processing Record 34 of Set 5 | itoman
# Processing Record 35 of Set 5 | silver city
# Processing Record 36 of Set 5 | ketchikan
# Processing Record 37 of Set 5 | birao
# Processing Record 38 of Set 5 | dikson
# Processing Record 39 of Set 5 | nabire
# Processing Record 40 of Set 5 | bestobe
# Processing Record 41 of Set 5 | zapolyarnyy
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | hami
# Processing Record 44 of Set 5 | luderitz
# Processing Record 45 of Set 5 | morondava
# Processing Record 46 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 47 of Set 5 | bobrov
# Processing Record 48 of Set 5 | geraldton
# Processing Record 49 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 50 of Set 5 | lamu
# Processing Record 1 of Set 6 | kloulklubed
# Processing Record 2 of Set 6 | namuac
# Processing Record 3 of Set 6 | zeya
# Processing Record 4 of Set 6 | nome
# Processing Record 5 of Set 6 | aracoiaba
# Processing Record 6 of Set 6 | lingao
# Processing Record 7 of Set 6 | chumikan
# Processing Record 8 of Set 6 | tilichiki
# Processing Record 9 of Set 6 | qui nhon
# Processing Record 10 of Set 6 | flores
# Processing Record 11 of Set 6 | atbasar
# Processing Record 12 of Set 6 | kijang
# Processing Record 13 of Set 6 | khatanga
# Processing Record 14 of Set 6 | siocon
# Processing Record 15 of Set 6 | kawalu
# Processing Record 16 of Set 6 | grindavik
# Processing Record 17 of Set 6 | preobrazheniye
# Processing Record 18 of Set 6 | sampit
# Processing Record 19 of Set 6 | townsville
# Processing Record 20 of Set 6 | salgar
# Processing Record 21 of Set 6 | richards bay
# Processing Record 22 of Set 6 | yataity
# Processing Record 23 of Set 6 | biltine
# Processing Record 24 of Set 6 | van wert
# Processing Record 25 of Set 6 | buala
# Processing Record 26 of Set 6 | trat
# Processing Record 27 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 6 | mogadishu
# Processing Record 29 of Set 6 | canillo
# Processing Record 30 of Set 6 | saskylakh
# Processing Record 31 of Set 6 | komsomolskiy
# Processing Record 32 of Set 6 | salalah
# Processing Record 33 of Set 6 | kizhinga
# Processing Record 34 of Set 6 | jumla
# Processing Record 35 of Set 6 | tarata
# Processing Record 36 of Set 6 | viedma
# Processing Record 37 of Set 6 | bambous virieux
# Processing Record 38 of Set 6 | svetlyy
# Processing Record 39 of Set 6 | bayonne
# Processing Record 40 of Set 6 | takoradi
# Processing Record 41 of Set 6 | beaverlodge
# Processing Record 42 of Set 6 | izhma
# Processing Record 43 of Set 6 | dum duma
# Processing Record 44 of Set 6 | kruisfontein
# Processing Record 45 of Set 6 | kungurtug
# Processing Record 46 of Set 6 | mount isa
# Processing Record 47 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 48 of Set 6 | appingedam
# Processing Record 49 of Set 6 | ilulissat
# Processing Record 50 of Set 6 | fort wellington
# Processing Record 1 of Set 7 | cockburn town
# Processing Record 2 of Set 7 | pitelino
# Processing Record 3 of Set 7 | bilibino
# Processing Record 4 of Set 7 | bharwari
# Processing Record 5 of Set 7 | vagur
# Processing Record 6 of Set 7 | manta
# Processing Record 7 of Set 7 | isangel
# Processing Record 8 of Set 7 | sawakin
# Processing Record 9 of Set 7 | bentiu
# Processing Record 10 of Set 7 | tabukiniberu
# City not found. Skipping...
# Processing Record 11 of Set 7 | sept-iles
# Processing Record 12 of Set 7 | laguna
# Processing Record 13 of Set 7 | cherskiy
# Processing Record 14 of Set 7 | iquitos
# Processing Record 15 of Set 7 | nyaunglebin
# Processing Record 16 of Set 7 | dudinka
# Processing Record 17 of Set 7 | ngunguru
# Processing Record 18 of Set 7 | chernigovka
# Processing Record 19 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 7 | tucurui
# Processing Record 21 of Set 7 | bhadrachalam
# Processing Record 22 of Set 7 | kaitangata
# Processing Record 23 of Set 7 | mayumba
# Processing Record 24 of Set 7 | codrington
# Processing Record 25 of Set 7 | cayenne
# Processing Record 26 of Set 7 | shar
# Processing Record 27 of Set 7 | susanville
# Processing Record 28 of Set 7 | sulina
# Processing Record 29 of Set 7 | mountain home
# Processing Record 30 of Set 7 | port elizabeth
# Processing Record 31 of Set 7 | hoyanger
# Processing Record 32 of Set 7 | banikoara
# Processing Record 33 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 34 of Set 7 | chauny
# Processing Record 35 of Set 7 | zhezkazgan
# Processing Record 36 of Set 7 | broome
# Processing Record 37 of Set 7 | turiacu
# Processing Record 38 of Set 7 | saint-joseph
# Processing Record 39 of Set 7 | santa cruz
# Processing Record 40 of Set 7 | gobabis
# Processing Record 41 of Set 7 | gornopravdinsk
# Processing Record 42 of Set 7 | bogatyye saby
# Processing Record 43 of Set 7 | haines junction
# Processing Record 44 of Set 7 | leningradskiy
# Processing Record 45 of Set 7 | vizinga
# Processing Record 46 of Set 7 | saint-augustin
# Processing Record 47 of Set 7 | bousse
# Processing Record 48 of Set 7 | catamarca
# Processing Record 49 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 7 | mandera
# Processing Record 1 of Set 8 | jurado
# Processing Record 2 of Set 8 | yacuiba
# Processing Record 3 of Set 8 | belmonte
# Processing Record 4 of Set 8 | torbay
# Processing Record 5 of Set 8 | port jervis
# Processing Record 6 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 8 | santa helena de goias
# Processing Record 8 of Set 8 | san lawrenz
# Processing Record 9 of Set 8 | sitka
# Processing Record 10 of Set 8 | coihaique
# Processing Record 11 of Set 8 | verkhnevilyuysk
# Processing Record 12 of Set 8 | horn
# Processing Record 13 of Set 8 | manaus
# Processing Record 14 of Set 8 | riofrio
# Processing Record 15 of Set 8 | yatou
# Processing Record 16 of Set 8 | cairns
# Processing Record 17 of Set 8 | hamilton
# Processing Record 18 of Set 8 | russell
# Processing Record 19 of Set 8 | wad madani
# Processing Record 20 of Set 8 | hirara
# Processing Record 21 of Set 8 | camopi
# Processing Record 22 of Set 8 | kuminskiy
# Processing Record 23 of Set 8 | bambanglipuro
# Processing Record 24 of Set 8 | venezuela
# Processing Record 25 of Set 8 | south lake tahoe
# Processing Record 26 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 8 | kahului
# Processing Record 28 of Set 8 | elk point
# Processing Record 29 of Set 8 | san quintin
# Processing Record 30 of Set 8 | shreveport
# Processing Record 31 of Set 8 | bathsheba
# Processing Record 32 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 8 | wejherowo
# Processing Record 34 of Set 8 | krasnyy kholm
# Processing Record 35 of Set 8 | bakaly
# Processing Record 36 of Set 8 | mayo
# Processing Record 37 of Set 8 | topolobampo
# Processing Record 38 of Set 8 | suleya
# Processing Record 39 of Set 8 | korla
# Processing Record 40 of Set 8 | tarnogskiy gorodok
# Processing Record 41 of Set 8 | shibetsu
# Processing Record 42 of Set 8 | maracacume
# Processing Record 43 of Set 8 | nuqui
# Processing Record 44 of Set 8 | uvira
# Processing Record 45 of Set 8 | faya
# Processing Record 46 of Set 8 | biga
# Processing Record 47 of Set 8 | khani
# Processing Record 48 of Set 8 | henties bay
# Processing Record 49 of Set 8 | marawi
# Processing Record 50 of Set 8 | roald
# Processing Record 1 of Set 9 | bayan
# Processing Record 2 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 3 of Set 9 | pouembout
# Processing Record 4 of Set 9 | shakhtinsk
# Processing Record 5 of Set 9 | inuvik
# Processing Record 6 of Set 9 | tuatapere
# Processing Record 7 of Set 9 | vitim
# Processing Record 8 of Set 9 | alofi
# Processing Record 9 of Set 9 | dolores hidalgo
# Processing Record 10 of Set 9 | hasaki
# Processing Record 11 of Set 9 | grand-santi
# Processing Record 12 of Set 9 | zaysan
# Processing Record 13 of Set 9 | shangrao
# Processing Record 14 of Set 9 | ixtapa
# Processing Record 15 of Set 9 | tarnow
# Processing Record 16 of Set 9 | nantucket
# Processing Record 17 of Set 9 | acurenam
# Processing Record 18 of Set 9 | arica
# Processing Record 19 of Set 9 | salekhard
# Processing Record 20 of Set 9 | cidreira
# Processing Record 21 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 22 of Set 9 | broken hill
# Processing Record 23 of Set 9 | coquimbo
# Processing Record 24 of Set 9 | puerto cabello
# Processing Record 25 of Set 9 | diamantino
# Processing Record 26 of Set 9 | meulaboh
# Processing Record 27 of Set 9 | mahina
# Processing Record 28 of Set 9 | kuala terengganu
# Processing Record 29 of Set 9 | kenai
# Processing Record 30 of Set 9 | jizan
# Processing Record 31 of Set 9 | pachora
# Processing Record 32 of Set 9 | panjakent
# Processing Record 33 of Set 9 | palmer
# Processing Record 34 of Set 9 | caldas
# Processing Record 35 of Set 9 | ryotsu
# Processing Record 36 of Set 9 | cabo san lucas
# Processing Record 37 of Set 9 | dubai
# Processing Record 38 of Set 9 | muvattupula
# Processing Record 39 of Set 9 | wattegama
# Processing Record 40 of Set 9 | mitsamiouli
# Processing Record 41 of Set 9 | jawhar
# Processing Record 42 of Set 9 | quelimane
# Processing Record 43 of Set 9 | dvinskoy
# Processing Record 44 of Set 9 | tuensang
# Processing Record 45 of Set 9 | jaciara
# Processing Record 46 of Set 9 | tabou
# Processing Record 47 of Set 9 | libourne
# Processing Record 48 of Set 9 | puerto escondido
# Processing Record 49 of Set 9 | ulaangom
# Processing Record 50 of Set 9 | sao filipe
# Processing Record 1 of Set 10 | saint anthony
# Processing Record 2 of Set 10 | kulhudhuffushi
# Processing Record 3 of Set 10 | pavilosta
# Processing Record 4 of Set 10 | znamenskoye
# Processing Record 5 of Set 10 | senador jose porfirio
# Processing Record 6 of Set 10 | aanekoski
# Processing Record 7 of Set 10 | asfi
# Processing Record 8 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 9 of Set 10 | kolomak
# Processing Record 10 of Set 10 | gerash
# Processing Record 11 of Set 10 | makakilo city
# Processing Record 12 of Set 10 | coulihaut
# City not found. Skipping...
# Processing Record 13 of Set 10 | capim grosso
# Processing Record 14 of Set 10 | vilhena
# Processing Record 15 of Set 10 | la ronge
# Processing Record 16 of Set 10 | olafsvik
# Processing Record 17 of Set 10 | ahipara
# Processing Record 18 of Set 10 | flinders
# Processing Record 19 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | san policarpo
# Processing Record 22 of Set 10 | bor
# Processing Record 23 of Set 10 | okhotsk
# Processing Record 24 of Set 10 | champerico
# Processing Record 25 of Set 10 | beira
# Processing Record 26 of Set 10 | marquette
# Processing Record 27 of Set 10 | cristalina
# Processing Record 28 of Set 10 | irbeyskoye
# Processing Record 29 of Set 10 | palauig
# Processing Record 30 of Set 10 | andra
# Processing Record 31 of Set 10 | bulgan
# Processing Record 32 of Set 10 | zelenoborsk
# Processing Record 33 of Set 10 | grand gaube
# Processing Record 34 of Set 10 | seoul
# Processing Record 35 of Set 10 | klaksvik
# Processing Record 36 of Set 10 | vao
# Processing Record 37 of Set 10 | kang
# Processing Record 38 of Set 10 | virden
# Processing Record 39 of Set 10 | mulege
# Processing Record 40 of Set 10 | port augusta
# Processing Record 41 of Set 10 | kadipur
# Processing Record 42 of Set 10 | buza
# Processing Record 43 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 10 | kaiyuan
# Processing Record 45 of Set 10 | zamhlay
# City not found. Skipping...
# Processing Record 46 of Set 10 | paramonga
# Processing Record 47 of Set 10 | guayaramerin
# Processing Record 48 of Set 10 | northam
# Processing Record 49 of Set 10 | baoqing
# Processing Record 50 of Set 10 | awjilah
# Processing Record 1 of Set 11 | chunskiy
# Processing Record 2 of Set 11 | muika
# City not found. Skipping...
# Processing Record 3 of Set 11 | nhulunbuy
# Processing Record 4 of Set 11 | wana
# Processing Record 5 of Set 11 | lorengau
# Processing Record 6 of Set 11 | itarema
# Processing Record 7 of Set 11 | derzhavinsk
# Processing Record 8 of Set 11 | skjervoy
# Processing Record 9 of Set 11 | kholodnyy
# Processing Record 10 of Set 11 | mecca
# Processing Record 11 of Set 11 | kurchum
# Processing Record 12 of Set 11 | balaipungut
# Processing Record 13 of Set 11 | sanchor
# Processing Record 14 of Set 11 | seymchan
# Processing Record 15 of Set 11 | nizhniy baskunchak
# Processing Record 16 of Set 11 | ngaoundere
# Processing Record 17 of Set 11 | upata
# Processing Record 18 of Set 11 | takaka
# Processing Record 19 of Set 11 | san ramon de la nueva oran
# Processing Record 20 of Set 11 | dukat
# Processing Record 21 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 22 of Set 11 | baruun-urt
# Processing Record 23 of Set 11 | tazovskiy
# Processing Record 24 of Set 11 | nemuro
# Processing Record 25 of Set 11 | havre-saint-pierre
# Processing Record 26 of Set 11 | livingston
# Processing Record 27 of Set 11 | sarai mir
# Processing Record 28 of Set 11 | sobolevo
# Processing Record 29 of Set 11 | chicama
# Processing Record 30 of Set 11 | batagay-alyta
# Processing Record 31 of Set 11 | tancheng
# Processing Record 32 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 33 of Set 11 | noumea
# Processing Record 34 of Set 11 | senanga
# Processing Record 35 of Set 11 | paamiut
# Processing Record 36 of Set 11 | caravelas
# Processing Record 37 of Set 11 | karratha
# Processing Record 38 of Set 11 | macapa
# Processing Record 39 of Set 11 | urucara
# Processing Record 40 of Set 11 | slave lake
# Processing Record 41 of Set 11 | san carlos del zulia
# Processing Record 42 of Set 11 | atherton
# Processing Record 43 of Set 11 | langsa
# Processing Record 44 of Set 11 | ust-nera
# Processing Record 45 of Set 11 | oussouye
# Processing Record 46 of Set 11 | fukue
# Processing Record 47 of Set 11 | murud
# Processing Record 48 of Set 11 | harper
# Processing Record 49 of Set 11 | cururupu
# Processing Record 50 of Set 11 | kez
# Processing Record 1 of Set 12 | fortuna
# Processing Record 2 of Set 12 | sur
# Processing Record 3 of Set 12 | beringovskiy
# Processing Record 4 of Set 12 | saint-denis
# Processing Record 5 of Set 12 | rio grande
# Processing Record 6 of Set 12 | harrison
# Processing Record 7 of Set 12 | ossora
# Processing Record 8 of Set 12 | burica
# City not found. Skipping...
# Processing Record 9 of Set 12 | tomatlan
# Processing Record 10 of Set 12 | buraydah
# Processing Record 11 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 12 | cacoal
# Processing Record 14 of Set 12 | port moresby
# Processing Record 15 of Set 12 | paita
# Processing Record 16 of Set 12 | belyy yar
# Processing Record 17 of Set 12 | rosa zarate
# Processing Record 18 of Set 12 | pimenta bueno
# Processing Record 19 of Set 12 | ambilobe
# Processing Record 20 of Set 12 | chapais
# Processing Record 21 of Set 12 | bandarbeyla
# Processing Record 22 of Set 12 | yeppoon
# Processing Record 23 of Set 12 | rocha
# Processing Record 24 of Set 12 | raudeberg
# Processing Record 25 of Set 12 | ojinaga
# Processing Record 26 of Set 12 | sunyani
# Processing Record 27 of Set 12 | mongoumba
# Processing Record 28 of Set 12 | rennes
# Processing Record 29 of Set 12 | zarand
# Processing Record 30 of Set 12 | north bend
# Processing Record 31 of Set 12 | sunland park
# Processing Record 32 of Set 12 | chiredzi
# Processing Record 33 of Set 12 | khonsa
# Processing Record 34 of Set 12 | kallidaikurichchi
# Processing Record 35 of Set 12 | abapo
# Processing Record 36 of Set 12 | kununurra
# Processing Record 37 of Set 12 | lacombe
# Processing Record 38 of Set 12 | man
# Processing Record 39 of Set 12 | kazachinskoye
# Processing Record 40 of Set 12 | kavaratti
# Processing Record 41 of Set 12 | katsuura
# Processing Record 42 of Set 12 | novikovo
# Processing Record 43 of Set 12 | matay
# Processing Record 44 of Set 12 | palu
# Processing Record 45 of Set 12 | voka
# Processing Record 46 of Set 12 | monticello
# Processing Record 47 of Set 12 | houma
# Processing Record 48 of Set 12 | leeton
# Processing Record 49 of Set 12 | kalvarija
# Processing Record 50 of Set 12 | purpe
# Processing Record 1 of Set 13 | billings
# Processing Record 2 of Set 13 | plaisance-du-touch
# Processing Record 3 of Set 13 | bomet
# Processing Record 4 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 13 | dingle
# Processing Record 7 of Set 13 | flin flon
# Processing Record 8 of Set 13 | floro
# Processing Record 9 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 13 | owando
# Processing Record 11 of Set 13 | wewak
# Processing Record 12 of Set 13 | anahuac
# Processing Record 13 of Set 13 | yumbe
# Processing Record 14 of Set 13 | santa cruz de tenerife
# Processing Record 15 of Set 13 | braila
# Processing Record 16 of Set 13 | segezha
# Processing Record 17 of Set 13 | olinda
# Processing Record 18 of Set 13 | bongandanga
# Processing Record 19 of Set 13 | rocky mountain house
# Processing Record 20 of Set 13 | riyadh
# Processing Record 21 of Set 13 | severo-yeniseyskiy
# Processing Record 22 of Set 13 | eureka
# Processing Record 23 of Set 13 | dekoa
# City not found. Skipping...
# Processing Record 24 of Set 13 | half moon bay
# Processing Record 25 of Set 13 | impfondo
# Processing Record 26 of Set 13 | kidal
# Processing Record 27 of Set 13 | mamlyutka
# Processing Record 28 of Set 13 | agadir
# Processing Record 29 of Set 13 | darnah
# Processing Record 30 of Set 13 | eregli
# Processing Record 31 of Set 13 | colares
# Processing Record 32 of Set 13 | kargopol
# Processing Record 33 of Set 13 | casma
# Processing Record 34 of Set 13 | hovd
# Processing Record 35 of Set 13 | marsa matruh
# Processing Record 36 of Set 13 | tumarbong
# Processing Record 37 of Set 13 | kavieng
# Processing Record 38 of Set 13 | mana
# Processing Record 39 of Set 13 | zhigansk
# Processing Record 40 of Set 13 | agropoli
# Processing Record 41 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 42 of Set 13 | mason city
# Processing Record 43 of Set 13 | kosh-agach
# Processing Record 44 of Set 13 | thomastown
# Processing Record 45 of Set 13 | san nicolas
# Processing Record 46 of Set 13 | ialibu
# Processing Record 47 of Set 13 | gamba
# Processing Record 48 of Set 13 | solnechnyy
# Processing Record 49 of Set 13 | teguise
# Processing Record 50 of Set 13 | hoi an
# Processing Record 1 of Set 14 | san rafael
# Processing Record 2 of Set 14 | aykhal
# Processing Record 3 of Set 14 | melendugno
# Processing Record 4 of Set 14 | mwene-ditu
# Processing Record 5 of Set 14 | sao francisco
# Processing Record 6 of Set 14 | umm kaddadah
# Processing Record 7 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 8 of Set 14 | oktyabrskoye
# Processing Record 9 of Set 14 | kerman
# Processing Record 10 of Set 14 | ekhabi
# Processing Record 11 of Set 14 | ranong
# Processing Record 12 of Set 14 | chipinge
# Processing Record 13 of Set 14 | japura
# Processing Record 14 of Set 14 | najran
# Processing Record 15 of Set 14 | nam tha
# City not found. Skipping...
# Processing Record 16 of Set 14 | xaghra
# Processing Record 17 of Set 14 | pauini
# Processing Record 18 of Set 14 | bad ems
# Processing Record 19 of Set 14 | guilin
# Processing Record 20 of Set 14 | calabozo
# Processing Record 21 of Set 14 | padang
# Processing Record 22 of Set 14 | barcelos
# Processing Record 23 of Set 14 | turinskaya sloboda
# Processing Record 24 of Set 14 | carballo
# Processing Record 25 of Set 14 | heishan
# Processing Record 26 of Set 14 | djenne
# Processing Record 27 of Set 14 | tari
# Processing Record 28 of Set 14 | jalu
# Processing Record 29 of Set 14 | pangody
# Processing Record 30 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 32 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 14 | saint-pierre
# Processing Record 34 of Set 14 | mitchell
# Processing Record 35 of Set 14 | mezen
# Processing Record 36 of Set 14 | fantanele
# Processing Record 37 of Set 14 | te anau
# Processing Record 38 of Set 14 | baculin
# Processing Record 39 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 14 | nyurba
# Processing Record 41 of Set 14 | kurilsk
# Processing Record 42 of Set 14 | ekimchan
# Processing Record 43 of Set 14 | taguatinga
# Processing Record 44 of Set 14 | sangueya
# Processing Record 45 of Set 14 | vrangel
# Processing Record 46 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 14 | zirgan
# Processing Record 48 of Set 14 | samana
# Processing Record 49 of Set 14 | acapulco
# Processing Record 50 of Set 14 | horta
# Processing Record 1 of Set 15 | gorontalo
# Processing Record 2 of Set 15 | ishigaki
# Processing Record 3 of Set 15 | melioratorov
# Processing Record 4 of Set 15 | koprivstica
# Processing Record 5 of Set 15 | bosanska kostajnica
# Processing Record 6 of Set 15 | kargasok
# Processing Record 7 of Set 15 | luanda
# Processing Record 8 of Set 15 | goure
# Processing Record 9 of Set 15 | uzhhorod
# Processing Record 10 of Set 15 | priekule
# Processing Record 11 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 12 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 15 | sarangpur
# Processing Record 14 of Set 15 | papara
# Processing Record 15 of Set 15 | gazanjyk
# Processing Record 16 of Set 15 | paka
# Processing Record 17 of Set 15 | salta
# Processing Record 18 of Set 15 | murgab
# Processing Record 19 of Set 15 | astara
# Processing Record 20 of Set 15 | beroroha
# Processing Record 21 of Set 15 | yar-sale
# Processing Record 22 of Set 15 | tigil
# Processing Record 23 of Set 15 | bang saphan
# Processing Record 24 of Set 15 | yangambi
# Processing Record 25 of Set 15 | nieuw amsterdam
# Processing Record 26 of Set 15 | aketi
# Processing Record 27 of Set 15 | senneterre
# Processing Record 28 of Set 15 | san jose
# Processing Record 29 of Set 15 | krasnokamensk
# Processing Record 30 of Set 15 | mandalgovi
# Processing Record 31 of Set 15 | kirakira
# Processing Record 32 of Set 15 | prince rupert
# Processing Record 33 of Set 15 | banda aceh
# Processing Record 34 of Set 15 | shieli
# Processing Record 35 of Set 15 | santa isabel do rio negro
# Processing Record 36 of Set 15 | nabannagan
# Processing Record 37 of Set 15 | martinsville
# Processing Record 38 of Set 15 | tres picos
# Processing Record 39 of Set 15 | pangnirtung
# Processing Record 40 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 41 of Set 15 | sao caetano de odivelas
# Processing Record 42 of Set 15 | san simon de la laguna
# Processing Record 43 of Set 15 | nagato
# Processing Record 44 of Set 15 | pyshchug
# Processing Record 45 of Set 15 | rochefort
# Processing Record 46 of Set 15 | dawlatabad
# Processing Record 47 of Set 15 | petatlan
# Processing Record 48 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 49 of Set 15 | szczytno
# Processing Record 50 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 1 of Set 16 | deputatskiy
# Processing Record 2 of Set 16 | arandis
# Processing Record 3 of Set 16 | sao joao da barra
# Processing Record 4 of Set 16 | hualmay
# Processing Record 5 of Set 16 | merauke
# Processing Record 6 of Set 16 | guisa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.02,
#   'Humidity': 76,
#   'Cloudiness': 22,
#   'Wind Speed': 14.41,
#   'Weather Description': 'few clouds'},
#  {'City': 'Sao Domingos',
#   'Country': 'BR',
#   'Lat': -13.3983,
#   'Lng': -46.3183,
#   'Max Temp': 87.76,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 7.02,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 37.06,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 48.88,
#   'Humidity': 85,
#   'Cloudiness': 66,
#   'Wind Speed': 8.68,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 77.04,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Weather Description': 'mist'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 51.58,
#   'Humidity': 66,
#   'Cloudiness': 91,
#   'Wind Speed': 15.17,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 77.5,
#   'Humidity': 91,
#   'Cloudiness': 56,
#   'Wind Speed': 4.09,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Freeport',
#   'Country': 'US',
#   'Lat': 40.6576,
#   'Lng': -73.5832,
#   'Max Temp': 99.28,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Weather Description': 'clear sky'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 51.55,
#   'Humidity': 85,
#   'Cloudiness': 10,
#   'Wind Speed': 1.72,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mayskiy',
#   'Country': 'RU',
#   'Lat': 47.6931,
#   'Lng': 40.1025,
#   'Max Temp': 63.81,
#   'Humidity': 63,
#   'Cloudiness': 65,
#   'Wind Speed': 7.47,
#   'Weather Description': 'light rain'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 36.61,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 7.16,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 73.44,
#   'Humidity': 64,
#   'Cloudiness': 86,
#   'Wind Speed': 15.7,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Thunder Bay',
#   'Country': 'CA',
#   'Lat': 48.4001,
#   'Lng': -89.3168,
#   'Max Temp': 70.45,
#   'Humidity': 59,
#   'Cloudiness': 90,
#   'Wind Speed': 5.53,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 69.96,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 48.52,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 8.37,
#   'Weather Description': 'clear sky'},
#  {'City': 'Piacabucu',
#   'Country': 'BR',
#   'Lat': -10.4056,
#   'Lng': -36.4344,
#   'Max Temp': 78.76,
#   'Humidity': 73,
#   'Cloudiness': 49,
#   'Wind Speed': 11.83,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 45.7,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Porto Velho',
#   'Country': 'BR',
#   'Lat': -8.7619,
#   'Lng': -63.9039,
#   'Max Temp': 99.16,
#   'Humidity': 27,
#   'Cloudiness': 13,
#   'Wind Speed': 2.59,
#   'Weather Description': 'few clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 39.31,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Weather Description': 'clear sky'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 67.21,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 10,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 80.58,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 102.04,
#   'Humidity': 20,
#   'Cloudiness': 82,
#   'Wind Speed': 7.67,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 48.27,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 95.54,
#   'Humidity': 42,
#   'Cloudiness': 82,
#   'Wind Speed': 16.49,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 76.21,
#   'Humidity': 85,
#   'Cloudiness': 78,
#   'Wind Speed': 6.64,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Celestun',
#   'Country': 'MX',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 88.63,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 9.66,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 66.07,
#   'Humidity': 69,
#   'Cloudiness': 19,
#   'Wind Speed': 21.97,
#   'Weather Description': 'few clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 88.02,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Weather Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 71.76,
#   'Humidity': 71,
#   'Cloudiness': 6,
#   'Wind Speed': 8.32,
#   'Weather Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 57.38,
#   'Humidity': 73,
#   'Cloudiness': 12,
#   'Wind Speed': 7,
#   'Weather Description': 'few clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 47.91,
#   'Humidity': 84,
#   'Cloudiness': 95,
#   'Wind Speed': 1.41,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Auki',
#   'Country': 'SB',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 76.68,
#   'Humidity': 89,
#   'Cloudiness': 31,
#   'Wind Speed': 3.78,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.76,
#   'Humidity': 86,
#   'Cloudiness': 94,
#   'Wind Speed': 5.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 52.75,
#   'Humidity': 92,
#   'Cloudiness': 64,
#   'Wind Speed': 3.78,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 94.62,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mvomero',
#   'Country': 'TZ',
#   'Lat': -6.25,
#   'Lng': 38.6667,
#   'Max Temp': 72.14,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 5.41,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 45.21,
#   'Humidity': 88,
#   'Cloudiness': 67,
#   'Wind Speed': 9.26,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Usinsk',
#   'Country': 'RU',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': 53.46,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 8.84,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lodja',
#   'Country': 'CD',
#   'Lat': -3.4833,
#   'Lng': 23.4333,
#   'Max Temp': 78.1,
#   'Humidity': 60,
#   'Cloudiness': 77,
#   'Wind Speed': 2.86,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 58.08,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Weather Description': 'light intensity drizzle'},
#  {'City': 'Malatya',
#   'Country': 'TR',
#   'Lat': 38.5,
#   'Lng': 38,
#   'Max Temp': 75.25,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 25.32,
#   'Weather Description': 'clear sky'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 73.31,
#   'Humidity': 85,
#   'Cloudiness': 19,
#   'Wind Speed': 8.86,
#   'Weather Description': 'few clouds'},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 44.15,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Berbera',
#   'Country': 'SO',
#   'Lat': 10.4396,
#   'Lng': 45.0143,
#   'Max Temp': 95.27,
#   'Humidity': 35,
#   'Cloudiness': 38,
#   'Wind Speed': 17.38,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 78.66,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Weather Description': 'clear sky'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 54.48,
#   'Humidity': 84,
#   'Cloudiness': 56,
#   'Wind Speed': 7.81,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.04,
#   'Humidity': 79,
#   'Cloudiness': 32,
#   'Wind Speed': 18.19,
#   'Weather Description': 'light rain'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 43.21,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 32.81,
#   'Humidity': 79,
#   'Cloudiness': 22,
#   'Wind Speed': 5.99,
#   'Weather Description': 'few clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 35.1,
#   'Humidity': 85,
#   'Cloudiness': 98,
#   'Wind Speed': 3.18,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 32.49,
#   'Humidity': 89,
#   'Cloudiness': 84,
#   'Wind Speed': 2.57,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sibolga',
#   'Country': 'ID',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 75.74,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 3.47,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 57.42,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3.47,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mizdah',
#   'Country': 'LY',
#   'Lat': 31.4451,
#   'Lng': 12.9801,
#   'Max Temp': 83.75,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 10.11,
#   'Weather Description': 'clear sky'},
#  {'City': 'Gizo',
#   'Country': 'SB',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 81.5,
#   'Humidity': 76,
#   'Cloudiness': 11,
#   'Wind Speed': 9.15,
#   'Weather Description': 'few clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 62.64,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 54.18,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 5.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kirillov',
#   'Country': 'RU',
#   'Lat': 59.863,
#   'Lng': 38.3813,
#   'Max Temp': 66.99,
#   'Humidity': 77,
#   'Cloudiness': 58,
#   'Wind Speed': 5.37,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 66.97,
#   'Humidity': 73,
#   'Cloudiness': 49,
#   'Wind Speed': 5.26,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kimparana',
#   'Country': 'ML',
#   'Lat': 12.8347,
#   'Lng': -4.9244,
#   'Max Temp': 77.56,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 11.63,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 60.85,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Weather Description': 'mist'},
#  {'City': 'Izmir',
#   'Country': 'TR',
#   'Lat': 38.4622,
#   'Lng': 27.0923,
#   'Max Temp': 90.91,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Weather Description': 'clear sky'},
#  {'City': 'Rincon',
#   'Country': 'US',
#   'Lat': 32.296,
#   'Lng': -81.2354,
#   'Max Temp': 91.36,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 37.94,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.15,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kudahuvadhoo',
#   'Country': 'MV',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 82.99,
#   'Humidity': 72,
#   'Cloudiness': 98,
#   'Wind Speed': 11.79,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 94.35,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Menton',
#   'Country': 'FR',
#   'Lat': 43.7765,
#   'Lng': 7.5044,
#   'Max Temp': 89.11,
#   'Humidity': 79,
#   'Cloudiness': 52,
#   'Wind Speed': 5.59,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 73.04,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 5.23,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cedar City',
#   'Country': 'US',
#   'Lat': 37.6775,
#   'Lng': -113.0619,
#   'Max Temp': 86.97,
#   'Humidity': 16,
#   'Cloudiness': 40,
#   'Wind Speed': 23.02,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Tarko-Sale',
#   'Country': 'RU',
#   'Lat': 64.9225,
#   'Lng': 77.785,
#   'Max Temp': 56.32,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 6.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 49.12,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 50.74,
#   'Humidity': 73,
#   'Cloudiness': 69,
#   'Wind Speed': 5.03,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mareeba',
#   'Country': 'AU',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 56.44,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 2.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 81.52,
#   'Humidity': 60,
#   'Cloudiness': 69,
#   'Wind Speed': 2.19,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 55.4,
#   'Humidity': 78,
#   'Cloudiness': 41,
#   'Wind Speed': 8.7,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 46.44,
#   'Humidity': 63,
#   'Cloudiness': 59,
#   'Wind Speed': 9.75,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 58.87,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 6.38,
#   'Weather Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 51.64,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 19.71,
#   'Weather Description': 'light rain'},
#  {'City': 'Gillette',
#   'Country': 'US',
#   'Lat': 44.2911,
#   'Lng': -105.5022,
#   'Max Temp': 77.92,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bontang',
#   'Country': 'ID',
#   'Lat': 0.1333,
#   'Lng': 117.5,
#   'Max Temp': 76.93,
#   'Humidity': 90,
#   'Cloudiness': 58,
#   'Wind Speed': 7.67,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kalmunai',
#   'Country': 'LK',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 81.03,
#   'Humidity': 79,
#   'Cloudiness': 62,
#   'Wind Speed': 3.78,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 51.78,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ponta Delgada',
#   'Country': 'PT',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 72.32,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Minab',
#   'Country': 'IR',
#   'Lat': 27.1467,
#   'Lng': 57.0801,
#   'Max Temp': 93.9,
#   'Humidity': 53,
#   'Cloudiness': 79,
#   'Wind Speed': 2.46,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Byron Bay',
#   'Country': 'AU',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 55.71,
#   'Humidity': 85,
#   'Cloudiness': 52,
#   'Wind Speed': 10.87,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Riverton',
#   'Country': 'US',
#   'Lat': 40.5219,
#   'Lng': -111.9391,
#   'Max Temp': 95.18,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Weather Description': 'clear sky'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 56.34,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Weather Description': 'clear sky'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 48.36,
#   'Humidity': 69,
#   'Cloudiness': 35,
#   'Wind Speed': 4.21,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Polovinnoye',
#   'Country': 'RU',
#   'Lat': 54.7914,
#   'Lng': 65.9864,
#   'Max Temp': 56.59,
#   'Humidity': 77,
#   'Cloudiness': 39,
#   'Wind Speed': 3.76,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 64.74,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 7.58,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 80.28,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Weather Description': 'light rain'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 55.71,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 19.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 64.56,
#   'Humidity': 59,
#   'Cloudiness': 86,
#   'Wind Speed': 17,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.56,
#   'Humidity': 93,
#   'Cloudiness': 93,
#   'Wind Speed': 5.28,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Poum',
#   'Country': 'NC',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 74.93,
#   'Humidity': 80,
#   'Cloudiness': 7,
#   'Wind Speed': 11.86,
#   'Weather Description': 'clear sky'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 72.01,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 4.45,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 41.16,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 0.87,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Turbat',
#   'Country': 'PK',
#   'Lat': 26.0023,
#   'Lng': 63.044,
#   'Max Temp': 84.24,
#   'Humidity': 75,
#   'Cloudiness': 78,
#   'Wind Speed': 11.68,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Tubuala',
#   'Country': 'PA',
#   'Lat': 9.5167,
#   'Lng': -79.0333,
#   'Max Temp': 82.26,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 3.76,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lasa',
#   'Country': 'IT',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 69.67,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Weather Description': 'light rain'},
#  {'City': 'Chau Doc',
#   'Country': 'VN',
#   'Lat': 10.7,
#   'Lng': 105.1167,
#   'Max Temp': 78.15,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.38,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Yumen',
#   'Country': 'CN',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 76.15,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 9.69,
#   'Weather Description': 'clear sky'},
#  {'City': 'Agadez',
#   'Country': 'NE',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 99.25,
#   'Humidity': 16,
#   'Cloudiness': 50,
#   'Wind Speed': 8.79,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.71,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.53,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Avera',
#   'Country': 'US',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 90.91,
#   'Humidity': 42,
#   'Cloudiness': 34,
#   'Wind Speed': 6.42,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 80.55,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Weather Description': 'few clouds'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 53.02,
#   'Humidity': 82,
#   'Cloudiness': 37,
#   'Wind Speed': 3.27,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Nuuk',
#   'Country': 'GL',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 61.41,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Antofagasta',
#   'Country': 'CL',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 60.08,
#   'Humidity': 71,
#   'Cloudiness': 92,
#   'Wind Speed': 7.31,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kieta',
#   'Country': 'PG',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 78.06,
#   'Humidity': 84,
#   'Cloudiness': 68,
#   'Wind Speed': 4.94,
#   'Weather Description': 'light rain'},
#  {'City': 'Fortuna Foothills',
#   'Country': 'US',
#   'Lat': 32.6578,
#   'Lng': -114.4119,
#   'Max Temp': 104.22,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Weather Description': 'clear sky'},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 53.64,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 10.54,
#   'Weather Description': 'light rain'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 48.04,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 69.21,
#   'Humidity': 65,
#   'Cloudiness': 68,
#   'Wind Speed': 7.94,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Dagua',
#   'Country': 'CO',
#   'Lat': 3.6569,
#   'Lng': -76.6886,
#   'Max Temp': 71.49,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 2.75,
#   'Weather Description': 'light rain'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 81.79,
#   'Humidity': 71,
#   'Cloudiness': 99,
#   'Wind Speed': 18.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Xining',
#   'Country': 'CN',
#   'Lat': 36.6167,
#   'Lng': 101.7667,
#   'Max Temp': 56.16,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 2.08,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 70.09,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Caconda',
#   'Country': 'AO',
#   'Lat': -13.7333,
#   'Lng': 15.0667,
#   'Max Temp': 66.24,
#   'Humidity': 29,
#   'Cloudiness': 57,
#   'Wind Speed': 4.47,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 41.5,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 15.12,
#   'Weather Description': 'light rain'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 49.91,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Weather Description': 'mist'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 69.39,
#   'Humidity': 85,
#   'Cloudiness': 72,
#   'Wind Speed': 13.94,
#   'Weather Description': 'light rain'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.03,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 8.21,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mollendo',
#   'Country': 'PE',
#   'Lat': -17.0231,
#   'Lng': -72.0147,
#   'Max Temp': 63.32,
#   'Humidity': 74,
#   'Cloudiness': 30,
#   'Wind Speed': 8.63,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Folkestone',
#   'Country': 'GB',
#   'Lat': 51.0833,
#   'Lng': 1.1833,
#   'Max Temp': 74.89,
#   'Humidity': 74,
#   'Cloudiness': 87,
#   'Wind Speed': 14,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 61,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Elesbao Veloso',
#   'Country': 'BR',
#   'Lat': -6.2019,
#   'Lng': -42.1403,
#   'Max Temp': 98.17,
#   'Humidity': 21,
#   'Cloudiness': 14,
#   'Wind Speed': 6.58,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 51.31,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 58.71,
#   'Humidity': 95,
#   'Cloudiness': 83,
#   'Wind Speed': 1.61,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 44.1,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 7.7,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sabya',
#   'Country': 'SA',
#   'Lat': 17.1495,
#   'Lng': 42.6254,
#   'Max Temp': 82.02,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 17.83,
#   'Weather Description': 'light rain'},
#  {'City': 'Charters Towers',
#   'Country': 'AU',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 55.17,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.41,
#   'Weather Description': 'clear sky'},
#  {'City': 'Stornoway',
#   'Country': 'GB',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp': 59.94,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Taltal',
#   'Country': 'CL',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 61.48,
#   'Humidity': 72,
#   'Cloudiness': 72,
#   'Wind Speed': 4.38,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Honiara',
#   'Country': 'SB',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 76.15,
#   'Humidity': 88,
#   'Cloudiness': 39,
#   'Wind Speed': 4.14,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 68.47,
#   'Humidity': 75,
#   'Cloudiness': 15,
#   'Wind Speed': 5.01,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kanashevo',
#   'Country': 'RU',
#   'Lat': 55.2169,
#   'Lng': 62.0634,
#   'Max Temp': 63.45,
#   'Humidity': 82,
#   'Cloudiness': 59,
#   'Wind Speed': 3.11,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 79.2,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Portree',
#   'Country': 'GB',
#   'Lat': 57.4129,
#   'Lng': -6.1942,
#   'Max Temp': 60.53,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.19,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 48.79,
#   'Humidity': 67,
#   'Cloudiness': 47,
#   'Wind Speed': 6.53,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Maningrida',
#   'Country': 'AU',
#   'Lat': -12.0667,
#   'Lng': 134.2667,
#   'Max Temp': 56.84,
#   'Humidity': 80,
#   'Cloudiness': 69,
#   'Wind Speed': 7.14,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 84.81,
#   'Humidity': 77,
#   'Cloudiness': 3,
#   'Wind Speed': 10.18,
#   'Weather Description': 'clear sky'},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 77.95,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Elizabeth City',
#   'Country': 'US',
#   'Lat': 36.2946,
#   'Lng': -76.2511,
#   'Max Temp': 97.79,
#   'Humidity': 32,
#   'Cloudiness': 87,
#   'Wind Speed': 9.8,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 70.18,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Weather Description': 'light rain'},
#  {'City': 'Havoysund',
#   'Country': 'NO',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 50.63,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 18.5,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Namie',
#   'Country': 'JP',
#   'Lat': 37.4833,
#   'Lng': 141,
#   'Max Temp': 72.01,
#   'Humidity': 83,
#   'Cloudiness': 61,
#   'Wind Speed': 3,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 80.71,
#   'Humidity': 74,
#   'Cloudiness': 35,
#   'Wind Speed': 4.52,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Batticaloa',
#   'Country': 'LK',
#   'Lat': 7.7102,
#   'Lng': 81.6924,
#   'Max Temp': 81.46,
#   'Humidity': 70,
#   'Cloudiness': 34,
#   'Wind Speed': 10.63,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Krasnoselkup',
#   'Country': 'RU',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': 56.17,
#   'Humidity': 92,
#   'Cloudiness': 47,
#   'Wind Speed': 3.56,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Cabinda',
#   'Country': 'AO',
#   'Lat': -5.55,
#   'Lng': 12.2,
#   'Max Temp': 71.11,
#   'Humidity': 86,
#   'Cloudiness': 47,
#   'Wind Speed': 7.56,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Sioux Lookout',
#   'Country': 'CA',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 73.47,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Biak',
#   'Country': 'ID',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 74.91,
#   'Humidity': 86,
#   'Cloudiness': 62,
#   'Wind Speed': 4.9,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Camacha',
#   'Country': 'PT',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 69.22,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Weather Description': 'few clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 80.53,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Weather Description': 'few clouds'},
#  {'City': 'Vadso',
#   'Country': 'NO',
#   'Lat': 70.0744,
#   'Lng': 29.7487,
#   'Max Temp': 58.08,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 71.35,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 35.62,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Weather Description': 'mist'},
#  {'City': 'Mehamn',
#   'Country': 'NO',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 51.75,
#   'Humidity': 93,
#   'Cloudiness': 82,
#   'Wind Speed': 13.8,
#   'Weather Description': 'drizzle'},
#  {'City': 'Loubomo',
#   'Country': 'CG',
#   'Lat': -4.1997,
#   'Lng': 12.6739,
#   'Max Temp': 76.03,
#   'Humidity': 63,
#   'Cloudiness': 93,
#   'Wind Speed': 9.37,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 68.09,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 71.92,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kupang',
#   'Country': 'ID',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 69.51,
#   'Humidity': 72,
#   'Cloudiness': 68,
#   'Wind Speed': 8.14,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Codajas',
#   'Country': 'BR',
#   'Lat': -3.8367,
#   'Lng': -62.0569,
#   'Max Temp': 85.3,
#   'Humidity': 62,
#   'Cloudiness': 92,
#   'Wind Speed': 2.42,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 50.45,
#   'Humidity': 81,
#   'Cloudiness': 67,
#   'Wind Speed': 6.67,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 61.9,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Brenham',
#   'Country': 'US',
#   'Lat': 30.1669,
#   'Lng': -96.3977,
#   'Max Temp': 96.82,
#   'Humidity': 36,
#   'Cloudiness': 26,
#   'Wind Speed': 8.28,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hohhot',
#   'Country': 'CN',
#   'Lat': 40.8106,
#   'Lng': 111.6522,
#   'Max Temp': 68.29,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Weather Description': 'clear sky'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 51.58,
#   'Humidity': 91,
#   'Cloudiness': 77,
#   'Wind Speed': 18.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 99.25,
#   'Humidity': 23,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Weather Description': 'few clouds'},
#  {'City': 'Zemio',
#   'Country': 'CF',
#   'Lat': 5.0314,
#   'Lng': 25.1361,
#   'Max Temp': 70.59,
#   'Humidity': 94,
#   'Cloudiness': 77,
#   'Wind Speed': 1.74,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 89.2,
#   'Humidity': 55,
#   'Cloudiness': 56,
#   'Wind Speed': 9.73,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Thomaston',
#   'Country': 'US',
#   'Lat': 32.8882,
#   'Lng': -84.3266,
#   'Max Temp': 90.09,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 33.85,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Weather Description': 'clear sky'},
#  {'City': 'Pitimbu',
#   'Country': 'BR',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 82.99,
#   'Humidity': 78,
#   'Cloudiness': 80,
#   'Wind Speed': 17.16,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Pokrovsk',
#   'Country': 'UA',
#   'Lat': 48.282,
#   'Lng': 37.1758,
#   'Max Temp': 67.24,
#   'Humidity': 64,
#   'Cloudiness': 80,
#   'Wind Speed': 5.66,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hobyo',
#   'Country': 'SO',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 76.78,
#   'Humidity': 82,
#   'Cloudiness': 48,
#   'Wind Speed': 28.77,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kismayo',
#   'Country': 'SO',
#   'Lat': -0.3582,
#   'Lng': 42.5454,
#   'Max Temp': 75.9,
#   'Humidity': 82,
#   'Cloudiness': 10,
#   'Wind Speed': 19.73,
#   'Weather Description': 'clear sky'},
#  {'City': 'Douglas',
#   'Country': 'US',
#   'Lat': 41.3,
#   'Lng': -96.167,
#   'Max Temp': 96.73,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Weather Description': 'clear sky'},
#  {'City': 'Uni',
#   'Country': 'RU',
#   'Lat': 57.7535,
#   'Lng': 51.4923,
#   'Max Temp': 66.42,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 2.66,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Andenes',
#   'Country': 'NO',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 50.94,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jieshi',
#   'Country': 'CN',
#   'Lat': 22.8134,
#   'Lng': 115.8257,
#   'Max Temp': 84.24,
#   'Humidity': 82,
#   'Cloudiness': 8,
#   'Wind Speed': 8.72,
#   'Weather Description': 'clear sky'},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 92.21,
#   'Humidity': 43,
#   'Cloudiness': 85,
#   'Wind Speed': 5.35,
#   'Weather Description': 'light rain'},
#  {'City': 'Verkhoyansk',
#   'Country': 'RU',
#   'Lat': 67.5447,
#   'Lng': 133.385,
#   'Max Temp': 58.6,
#   'Humidity': 89,
#   'Cloudiness': 61,
#   'Wind Speed': 3.49,
#   'Weather Description': 'light rain'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 64,
#   'Humidity': 90,
#   'Cloudiness': 15,
#   'Wind Speed': 3.89,
#   'Weather Description': 'few clouds'},
#  {'City': 'Sirjan',
#   'Country': 'IR',
#   'Lat': 29.452,
#   'Lng': 55.6814,
#   'Max Temp': 79.56,
#   'Humidity': 41,
#   'Cloudiness': 25,
#   'Wind Speed': 11.14,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Dunedin',
#   'Country': 'NZ',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 42.8,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 11.01,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 71.49,
#   'Humidity': 96,
#   'Cloudiness': 94,
#   'Wind Speed': 4.05,
#   'Weather Description': 'light rain'},
#  {'City': 'Shizuishan',
#   'Country': 'CN',
#   'Lat': 39.2333,
#   'Lng': 106.7694,
#   'Max Temp': 77.04,
#   'Humidity': 43,
#   'Cloudiness': 2,
#   'Wind Speed': 11.16,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kamaishi',
#   'Country': 'JP',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 69.87,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 45.7,
#   'Humidity': 87,
#   'Cloudiness': 53,
#   'Wind Speed': 3.74,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Saint-Paul',
#   'Country': 'RE',
#   'Lat': -21.0096,
#   'Lng': 55.2707,
#   'Max Temp': 69.91,
#   'Humidity': 77,
#   'Cloudiness': 60,
#   'Wind Speed': 1.81,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port Arthur',
#   'Country': 'CN',
#   'Lat': 38.8,
#   'Lng': 121.2667,
#   'Max Temp': 77.92,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 2.62,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mirnyy',
#   'Country': 'RU',
#   'Lat': 62.5353,
#   'Lng': 113.9611,
#   'Max Temp': 68.23,
#   'Humidity': 64,
#   'Cloudiness': 14,
#   'Wind Speed': 11.01,
#   'Weather Description': 'few clouds'},
#  {'City': 'Stokmarknes',
#   'Country': 'NO',
#   'Lat': 68.5646,
#   'Lng': 14.9108,
#   'Max Temp': 52.97,
#   'Humidity': 82,
#   'Cloudiness': 76,
#   'Wind Speed': 5.48,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Medea',
#   'Country': 'DZ',
#   'Lat': 36.2642,
#   'Lng': 2.7539,
#   'Max Temp': 84.99,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 7.74,
#   'Weather Description': 'clear sky'},
#  {'City': 'Camana',
#   'Country': 'PE',
#   'Lat': -16.6228,
#   'Lng': -72.7111,
#   'Max Temp': 63.86,
#   'Humidity': 73,
#   'Cloudiness': 39,
#   'Wind Speed': 8.37,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Aswan',
#   'Country': 'EG',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 95.9,
#   'Humidity': 15,
#   'Cloudiness': 2,
#   'Wind Speed': 11.88,
#   'Weather Description': 'clear sky'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 44.87,
#   'Humidity': 80,
#   'Cloudiness': 95,
#   'Wind Speed': 14.23,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lata',
#   'Country': 'PT',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 81.07,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 7.63,
#   'Weather Description': 'clear sky'},
#  {'City': 'Quatre Cocos',
#   'Country': 'MU',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 69.91,
#   'Humidity': 75,
#   'Cloudiness': 47,
#   'Wind Speed': 17.98,
#   'Weather Description': 'light rain'},
#  {'City': 'Bartica',
#   'Country': 'GY',
#   'Lat': 6.4,
#   'Lng': -58.6167,
#   'Max Temp': 80.92,
#   'Humidity': 92,
#   'Cloudiness': 53,
#   'Wind Speed': 4.5,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 47.23,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.27,
#   'Weather Description': 'light rain'},
#  {'City': 'San Andres Del Rabanedo',
#   'Country': 'ES',
#   'Lat': 42.6117,
#   'Lng': -5.6167,
#   'Max Temp': 92.79,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tessalit',
#   'Country': 'ML',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 104.9,
#   'Humidity': 9,
#   'Cloudiness': 71,
#   'Wind Speed': 6.67,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Laizhou',
#   'Country': 'CN',
#   'Lat': 37.1717,
#   'Lng': 119.9214,
#   'Max Temp': 70.57,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 1.61,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 53.46,
#   'Humidity': 85,
#   'Cloudiness': 88,
#   'Wind Speed': 9.71,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Itoman',
#   'Country': 'JP',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 83.7,
#   'Humidity': 83,
#   'Cloudiness': 80,
#   'Wind Speed': 6.42,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Silver City',
#   'Country': 'US',
#   'Lat': 32.7701,
#   'Lng': -108.2803,
#   'Max Temp': 87.67,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ketchikan',
#   'Country': 'US',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 57.76,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.29,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Birao',
#   'Country': 'CF',
#   'Lat': 10.2849,
#   'Lng': 22.7882,
#   'Max Temp': 74.89,
#   'Humidity': 87,
#   'Cloudiness': 62,
#   'Wind Speed': 4.92,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 54.09,
#   'Humidity': 71,
#   'Cloudiness': 85,
#   'Wind Speed': 10.78,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nabire',
#   'Country': 'ID',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 74.68,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 4.29,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bestobe',
#   'Country': 'KZ',
#   'Lat': 52.4994,
#   'Lng': 73.0975,
#   'Max Temp': 64.42,
#   'Humidity': 73,
#   'Cloudiness': 47,
#   'Wind Speed': 7.31,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Zapolyarnyy',
#   'Country': 'RU',
#   'Lat': 69.4154,
#   'Lng': 30.8136,
#   'Max Temp': 56.48,
#   'Humidity': 74,
#   'Cloudiness': 64,
#   'Wind Speed': 10.02,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 59.22,
#   'Humidity': 68,
#   'Cloudiness': 79,
#   'Wind Speed': 8.16,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 85.73,
#   'Humidity': 22,
#   'Cloudiness': 25,
#   'Wind Speed': 9.42,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 62.58,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 26.4,
#   'Weather Description': 'clear sky'},
#  {'City': 'Morondava',
#   'Country': 'MG',
#   'Lat': -20.2833,
#   'Lng': 44.2833,
#   'Max Temp': 73,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 9.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bobrov',
#   'Country': 'RU',
#   'Lat': 51.0961,
#   'Lng': 40.0333,
#   'Max Temp': 62.73,
#   'Humidity': 87,
#   'Cloudiness': 72,
#   'Wind Speed': 8.16,
#   'Weather Description': 'light rain'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 59.41,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 19.57,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lamu',
#   'Country': 'KE',
#   'Lat': -2.2717,
#   'Lng': 40.902,
#   'Max Temp': 75.42,
#   'Humidity': 79,
#   'Cloudiness': 9,
#   'Wind Speed': 17.2,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 77.5,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 12.17,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Namuac',
#   'Country': 'PH',
#   'Lat': 18.6109,
#   'Lng': 121.1657,
#   'Max Temp': 81.57,
#   'Humidity': 85,
#   'Cloudiness': 55,
#   'Wind Speed': 3.02,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Zeya',
#   'Country': 'RU',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 62.71,
#   'Humidity': 68,
#   'Cloudiness': 4,
#   'Wind Speed': 3.53,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 48.27,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Aracoiaba',
#   'Country': 'BR',
#   'Lat': -4.3711,
#   'Lng': -38.8142,
#   'Max Temp': 89.96,
#   'Humidity': 39,
#   'Cloudiness': 35,
#   'Wind Speed': 10.4,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Lingao',
#   'Country': 'CN',
#   'Lat': 19.9103,
#   'Lng': 109.6859,
#   'Max Temp': 81.01,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 3.13,
#   'Weather Description': 'clear sky'},
#  {'City': 'Chumikan',
#   'Country': 'RU',
#   'Lat': 54.7183,
#   'Lng': 135.315,
#   'Max Temp': 55.18,
#   'Humidity': 78,
#   'Cloudiness': 18,
#   'Wind Speed': 5.06,
#   'Weather Description': 'few clouds'},
#  {'City': 'Tilichiki',
#   'Country': 'RU',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 46.13,
#   'Humidity': 88,
#   'Cloudiness': 76,
#   'Wind Speed': 7.27,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Qui Nhon',
#   'Country': 'VN',
#   'Lat': 13.7667,
#   'Lng': 109.2333,
#   'Max Temp': 77.65,
#   'Humidity': 85,
#   'Cloudiness': 30,
#   'Wind Speed': 5.17,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Flores',
#   'Country': 'GT',
#   'Lat': 16.9226,
#   'Lng': -89.8994,
#   'Max Temp': 78.08,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.29,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Atbasar',
#   'Country': 'KZ',
#   'Lat': 51.8,
#   'Lng': 68.3333,
#   'Max Temp': 63.9,
#   'Humidity': 69,
#   'Cloudiness': 55,
#   'Wind Speed': 7.29,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kijang',
#   'Country': 'KR',
#   'Lat': 35.2442,
#   'Lng': 129.2139,
#   'Max Temp': 76.73,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 6.31,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 46,
#   'Humidity': 90,
#   'Cloudiness': 53,
#   'Wind Speed': 13.29,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Siocon',
#   'Country': 'PH',
#   'Lat': 7.7061,
#   'Lng': 122.1353,
#   'Max Temp': 78.71,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 4.05,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kawalu',
#   'Country': 'ID',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 71.6,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 1.54,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Grindavik',
#   'Country': 'IS',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 55.35,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
# ...
#   'Cloudiness': 36,
#   'Wind Speed': 2.86,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bad Ems',
#   'Country': 'DE',
#   'Lat': 50.3333,
#   'Lng': 7.7167,
#   'Max Temp': 78.22,
#   'Humidity': 58,
#   'Cloudiness': 73,
#   'Wind Speed': 2.8,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Guilin',
#   'Country': 'CN',
#   'Lat': 25.2819,
#   'Lng': 110.2864,
#   'Max Temp': 77.72,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 0.2,
#   'Weather Description': 'clear sky'},
#  {'City': 'Calabozo',
#   'Country': 'VE',
#   'Lat': 8.9242,
#   'Lng': -67.4293,
#   'Max Temp': 91.26,
#   'Humidity': 42,
#   'Cloudiness': 10,
#   'Wind Speed': 6.58,
#   'Weather Description': 'clear sky'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 77.77,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 4.76,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Barcelos',
#   'Country': 'PT',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp': 79.79,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 6.42,
#   'Weather Description': 'clear sky'},
#  {'City': 'Turinskaya Sloboda',
#   'Country': 'RU',
#   'Lat': 57.6232,
#   'Lng': 64.3858,
#   'Max Temp': 60.19,
#   'Humidity': 65,
#   'Cloudiness': 63,
#   'Wind Speed': 3.56,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Carballo',
#   'Country': 'ES',
#   'Lat': 43.213,
#   'Lng': -8.691,
#   'Max Temp': 80.02,
#   'Humidity': 71,
#   'Cloudiness': 6,
#   'Wind Speed': 6.93,
#   'Weather Description': 'clear sky'},
#  {'City': 'Heishan',
#   'Country': 'CN',
#   'Lat': 41.6892,
#   'Lng': 122.1128,
#   'Max Temp': 65.48,
#   'Humidity': 97,
#   'Cloudiness': 24,
#   'Wind Speed': 2.44,
#   'Weather Description': 'few clouds'},
#  {'City': 'Djenne',
#   'Country': 'ML',
#   'Lat': 13.9061,
#   'Lng': -4.5533,
#   'Max Temp': 84.85,
#   'Humidity': 56,
#   'Cloudiness': 97,
#   'Wind Speed': 7.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tari',
#   'Country': 'NG',
#   'Lat': 12.4086,
#   'Lng': 4.4914,
#   'Max Temp': 86.18,
#   'Humidity': 57,
#   'Cloudiness': 96,
#   'Wind Speed': 8.32,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jalu',
#   'Country': 'LY',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 91.24,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 8.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Pangody',
#   'Country': 'RU',
#   'Lat': 65.85,
#   'Lng': 74.4859,
#   'Max Temp': 52.36,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 18.21,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 69.48,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 23.02,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mitchell',
#   'Country': 'US',
#   'Lat': 43.7094,
#   'Lng': -98.0298,
#   'Max Temp': 87.78,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mezen',
#   'Country': 'RU',
#   'Lat': 65.8522,
#   'Lng': 44.24,
#   'Max Temp': 57.97,
#   'Humidity': 69,
#   'Cloudiness': 91,
#   'Wind Speed': 6.02,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Fantanele',
#   'Country': 'RO',
#   'Lat': 46.1167,
#   'Lng': 21.4,
#   'Max Temp': 92.91,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Weather Description': 'clear sky'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 37.18,
#   'Humidity': 94,
#   'Cloudiness': 94,
#   'Wind Speed': 0.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Baculin',
#   'Country': 'PH',
#   'Lat': 7.4525,
#   'Lng': 126.5842,
#   'Max Temp': 77.59,
#   'Humidity': 88,
#   'Cloudiness': 94,
#   'Wind Speed': 5.53,
#   'Weather Description': 'light rain'},
#  {'City': 'Nyurba',
#   'Country': 'RU',
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': 61.3,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 6.49,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kurilsk',
#   'Country': 'RU',
#   'Lat': 45.2333,
#   'Lng': 147.8833,
#   'Max Temp': 55.42,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 17.27,
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Ekimchan',
#   'Country': 'RU',
#   'Lat': 53.0667,
#   'Lng': 132.9667,
#   'Max Temp': 56.12,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 2.24,
#   'Weather Description': 'clear sky'},
#  {'City': 'Taguatinga',
#   'Country': 'BR',
#   'Lat': -12.3857,
#   'Lng': -46.5711,
#   'Max Temp': 92.95,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 6.42,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sangueya',
#   'Country': 'GN',
#   'Lat': 10.7,
#   'Lng': -14.3667,
#   'Max Temp': 76.87,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.41,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vrangel',
#   'Country': 'RU',
#   'Lat': 42.7297,
#   'Lng': 133.0839,
#   'Max Temp': 62.91,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Zirgan',
#   'Country': 'RU',
#   'Lat': 53.2222,
#   'Lng': 55.9185,
#   'Max Temp': 64.85,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 6.89,
#   'Weather Description': 'clear sky'},
#  {'City': 'Samana',
#   'Country': 'DO',
#   'Lat': 19.2056,
#   'Lng': -69.3369,
#   'Max Temp': 89.82,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Weather Description': 'few clouds'},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 85.82,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Horta',
#   'Country': 'PT',
#   'Lat': 38.5333,
#   'Lng': -28.6333,
#   'Max Temp': 78.44,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Gorontalo',
#   'Country': 'ID',
#   'Lat': 0.5412,
#   'Lng': 123.0595,
#   'Max Temp': 74.8,
#   'Humidity': 94,
#   'Cloudiness': 39,
#   'Wind Speed': 4.29,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ishigaki',
#   'Country': 'JP',
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 82.53,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Melioratorov',
#   'Country': 'RU',
#   'Lat': 57.2107,
#   'Lng': 65.6077,
#   'Max Temp': 64.78,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Weather Description': 'clear sky'},
#  {'City': 'Koprivstica',
#   'Country': 'RS',
#   'Lat': 43.2349,
#   'Lng': 22.6205,
#   'Max Temp': 81.86,
#   'Humidity': 32,
#   'Cloudiness': 3,
#   'Wind Speed': 3.56,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bosanska Kostajnica',
#   'Country': 'HR',
#   'Lat': 45.2159,
#   'Lng': 16.5444,
#   'Max Temp': 84.67,
#   'Humidity': 43,
#   'Cloudiness': 66,
#   'Wind Speed': 4.07,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kargasok',
#   'Country': 'RU',
#   'Lat': 59.0556,
#   'Lng': 80.8572,
#   'Max Temp': 55.2,
#   'Humidity': 67,
#   'Cloudiness': 86,
#   'Wind Speed': 5.46,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Luanda',
#   'Country': 'AO',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 69.26,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 8.28,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Goure',
#   'Country': 'NE',
#   'Lat': 13.9835,
#   'Lng': 10.2704,
#   'Max Temp': 86.02,
#   'Humidity': 36,
#   'Cloudiness': 71,
#   'Wind Speed': 6.73,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Uzhhorod',
#   'Country': 'UA',
#   'Lat': 48.6167,
#   'Lng': 22.3,
#   'Max Temp': 82.38,
#   'Humidity': 34,
#   'Cloudiness': 64,
#   'Wind Speed': 4.16,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Priekule',
#   'Country': 'LV',
#   'Lat': 56.4468,
#   'Lng': 21.5897,
#   'Max Temp': 63.72,
#   'Humidity': 78,
#   'Cloudiness': 80,
#   'Wind Speed': 7.72,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sarangpur',
#   'Country': 'IN',
#   'Lat': 23.5667,
#   'Lng': 76.4667,
#   'Max Temp': 75.85,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Weather Description': 'light rain'},
#  {'City': 'Papara',
#   'Country': 'BR',
#   'Lat': -3.9839,
#   'Lng': -38.7273,
#   'Max Temp': 88.84,
#   'Humidity': 39,
#   'Cloudiness': 21,
#   'Wind Speed': 10.31,
#   'Weather Description': 'few clouds'},
#  {'City': 'Gazanjyk',
#   'Country': 'TM',
#   'Lat': 39.2446,
#   'Lng': 55.5154,
#   'Max Temp': 83.5,
#   'Humidity': 49,
#   'Cloudiness': 3,
#   'Wind Speed': 15.57,
#   'Weather Description': 'clear sky'},
#  {'City': 'Paka',
#   'Country': 'MY',
#   'Lat': 4.6374,
#   'Lng': 103.4368,
#   'Max Temp': 79.18,
#   'Humidity': 85,
#   'Cloudiness': 91,
#   'Wind Speed': 4.34,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Salta',
#   'Country': 'AR',
#   'Lat': -24.7859,
#   'Lng': -65.4117,
#   'Max Temp': 76.57,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Murgab',
#   'Country': 'TM',
#   'Lat': 37.4966,
#   'Lng': 61.9714,
#   'Max Temp': 91.27,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Astara',
#   'Country': 'AZ',
#   'Lat': 38.5,
#   'Lng': 48.6667,
#   'Max Temp': 71.58,
#   'Humidity': 83,
#   'Cloudiness': 11,
#   'Wind Speed': 2.86,
#   'Weather Description': 'few clouds'},
#  {'City': 'Beroroha',
#   'Country': 'MG',
#   'Lat': -21.6667,
#   'Lng': 45.1667,
#   'Max Temp': 69.13,
#   'Humidity': 46,
#   'Cloudiness': 17,
#   'Wind Speed': 2.3,
#   'Weather Description': 'few clouds'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 50.29,
#   'Humidity': 79,
#   'Cloudiness': 88,
#   'Wind Speed': 15.82,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tigil',
#   'Country': 'RU',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 48.02,
#   'Humidity': 70,
#   'Cloudiness': 27,
#   'Wind Speed': 1.77,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bang Saphan',
#   'Country': 'TH',
#   'Lat': 11.2126,
#   'Lng': 99.5117,
#   'Max Temp': 76.24,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.21,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yangambi',
#   'Country': 'CD',
#   'Lat': 0.8102,
#   'Lng': 24.4336,
#   'Max Temp': 74.5,
#   'Humidity': 80,
#   'Cloudiness': 95,
#   'Wind Speed': 1.41,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nieuw Amsterdam',
#   'Country': 'SR',
#   'Lat': 5.8833,
#   'Lng': -55.0833,
#   'Max Temp': 91.56,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Weather Description': 'light intensity shower rain'},
#  {'City': 'Aketi',
#   'Country': 'CD',
#   'Lat': 2.7388,
#   'Lng': 23.7833,
#   'Max Temp': 74.03,
#   'Humidity': 81,
#   'Cloudiness': 50,
#   'Wind Speed': 0.54,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Senneterre',
#   'Country': 'CA',
#   'Lat': 48.3835,
#   'Lng': -77.2328,
#   'Max Temp': 74.86,
#   'Humidity': 49,
#   'Cloudiness': 80,
#   'Wind Speed': 9.84,
#   'Weather Description': 'broken clouds'},
#  {'City': 'San Jose',
#   'Country': 'US',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 81.54,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Weather Description': 'few clouds'},
#  {'City': 'Krasnokamensk',
#   'Country': 'RU',
#   'Lat': 50.0979,
#   'Lng': 118.0369,
#   'Max Temp': 61.83,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 3.38,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Mandalgovi',
#   'Country': 'MN',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 63.81,
#   'Humidity': 53,
#   'Cloudiness': 70,
#   'Wind Speed': 7.16,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kirakira',
#   'Country': 'SB',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 77.25,
#   'Humidity': 85,
#   'Cloudiness': 14,
#   'Wind Speed': 5.17,
#   'Weather Description': 'few clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 57.29,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Banda Aceh',
#   'Country': 'ID',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 78.49,
#   'Humidity': 85,
#   'Cloudiness': 77,
#   'Wind Speed': 4.25,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Shieli',
#   'Country': 'KZ',
#   'Lat': 44.1667,
#   'Lng': 66.75,
#   'Max Temp': 93.36,
#   'Humidity': 19,
#   'Cloudiness': 27,
#   'Wind Speed': 16.02,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Country': 'BR',
#   'Lat': -0.4139,
#   'Lng': -65.0192,
#   'Max Temp': 80.4,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 1.52,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nabannagan',
#   'Country': 'PH',
#   'Lat': 18.0715,
#   'Lng': 121.5338,
#   'Max Temp': 76.78,
#   'Humidity': 95,
#   'Cloudiness': 57,
#   'Wind Speed': 1.5,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Martinsville',
#   'Country': 'US',
#   'Lat': 36.6915,
#   'Lng': -79.8725,
#   'Max Temp': 94.17,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tres Picos',
#   'Country': 'MX',
#   'Lat': 15.8667,
#   'Lng': -93.5333,
#   'Max Temp': 79.86,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.74,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Weather Description': 'mist'},
#  {'City': 'Sao Caetano De Odivelas',
#   'Country': 'BR',
#   'Lat': -0.75,
#   'Lng': -48.02,
#   'Max Temp': 81.82,
#   'Humidity': 76,
#   'Cloudiness': 83,
#   'Wind Speed': 8.3,
#   'Weather Description': 'broken clouds'},
#  {'City': 'San Simon De La Laguna',
#   'Country': 'MX',
#   'Lat': 19.3,
#   'Lng': -100.0833,
#   'Max Temp': 62.8,
#   'Humidity': 74,
#   'Cloudiness': 96,
#   'Wind Speed': 3.65,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nagato',
#   'Country': 'JP',
#   'Lat': 34.3833,
#   'Lng': 131.2,
#   'Max Temp': 74.62,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pyshchug',
#   'Country': 'RU',
#   'Lat': 58.8873,
#   'Lng': 45.7134,
#   'Max Temp': 67.62,
#   'Humidity': 76,
#   'Cloudiness': 11,
#   'Wind Speed': 4.47,
#   'Weather Description': 'few clouds'},
#  {'City': 'Rochefort',
#   'Country': 'FR',
#   'Lat': 45.9167,
#   'Lng': -1,
#   'Max Temp': 69.85,
#   'Humidity': 75,
#   'Cloudiness': 8,
#   'Wind Speed': 8.01,
#   'Weather Description': 'clear sky'},
#  {'City': 'Dawlatabad',
#   'Country': 'AF',
#   'Lat': 36.4141,
#   'Lng': 64.9053,
#   'Max Temp': 95.52,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 18.05,
#   'Weather Description': 'clear sky'},
#  {'City': 'Petatlan',
#   'Country': 'MX',
#   'Lat': 17.5167,
#   'Lng': -101.2667,
#   'Max Temp': 91.2,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Szczytno',
#   'Country': 'PL',
#   'Lat': 53.5626,
#   'Lng': 20.9875,
#   'Max Temp': 64.54,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 4.68,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 48.47,
#   'Humidity': 71,
#   'Cloudiness': 88,
#   'Wind Speed': 4.23,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Arandis',
#   'Country': 'NA',
#   'Lat': -22.4167,
#   'Lng': 14.9667,
#   'Max Temp': 63.63,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 3.51,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 80.69,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 15.9,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 65.89,
#   'Humidity': 74,
#   'Cloudiness': 81,
#   'Wind Speed': 8.9,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Merauke',
#   'Country': 'ID',
#   'Lat': -8.4667,
#   'Lng': 140.3333,
#   'Max Temp': 75.34,
#   'Humidity': 91,
#   'Cloudiness': 48,
#   'Wind Speed': 12.12,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Guisa',
#   'Country': 'CU',
#   'Lat': 20.255,
#   'Lng': -76.5386,
#   'Max Temp': 86.5,
#   'Humidity': 63,
#   'Cloudiness': 83,
#   'Wind Speed': 7.85,
#   'Weather Description': 'broken clouds'}]

# %%
len(city_data)
# Out:
# 690

# %%
city_weather
# Out:
# {'coord': {'lon': -76.5386, 'lat': 20.255},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 86.5,
#   'feels_like': 93.25,
#   'temp_min': 86.5,
#   'temp_max': 86.5,
#   'pressure': 1016,
#   'humidity': 63,
#   'sea_level': 1016,
#   'grnd_level': 990},
#  'visibility': 10000,
#  'wind': {'speed': 7.85, 'deg': 106, 'gust': 13.73},
#  'clouds': {'all': 83},
#  'dt': 1658600597,
#  'sys': {'country': 'CU', 'sunrise': 1658572663, 'sunset': 1658620033},
#  'timezone': -14400,
#  'id': 3557332,
#  'name': 'Guisa',
#  'cod': 200}

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Butaritari      KI   3.0707  172.7902     82.02        76          22
# 1    Sao Domingos      BR -13.3983  -46.3183     87.76        24           0
# 2         Ushuaia      AR -54.8000  -68.3000     37.06        75          75
# 3  Port Macquarie      AU -31.4333  152.9167     48.88        85          66
# 4      Port Blair      IN  11.6667   92.7500     77.04        94          75
# 5       Busselton      AU -33.6500  115.3333     51.58        66          91
# 6          Vanimo      PG  -2.6741  141.3028     77.50        91          56
# 7        Freeport      US  40.6576  -73.5832     99.28        38           0
# 8           Airai      TL  -8.9266  125.4092     51.55        85          10
# 9         Mayskiy      RU  47.6931   40.1025     63.81        63          65
#
#    Wind Speed Weather Description
# 0       14.41          few clouds
# 1        7.02           clear sky
# 2       12.66       broken clouds
# 3        8.68       broken clouds
# 4        2.30                mist
# 5       15.17     overcast clouds
# 6        4.09       broken clouds
# 7       10.36           clear sky
# 8        1.72           clear sky
# 9        7.47          light rain

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City ID" )
